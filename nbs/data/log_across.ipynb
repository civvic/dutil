# %%
from pathlib import Path
from dutil.logger import Logger

# %%
nbs = '/'.join(find_dname().split('/')[:-2])
nbs
# Out:
# '/vic/dutil/nbs'

# %%
tgtid = find_msgs('# across target', msg_type='code', limit=1, dname=nbs+'/01_logger')[0].id

# %%
log = Logger(tgtid, nbs+'/01_logger')
# Out:
# [18:16:28.629] Mancha
# [18:16:28.604] la
# [18:16:28.578] de
# [18:16:28.451] lugar
# [18:16:28.426] algún
# [18:16:28.401] En
# [18:16:28.296] Some msg -> 284

# %%
log('asd')

# %%
log.show()
# Out:
# [18:17:20.907] asd
# [18:16:28.629] Mancha
# [18:16:28.604] la
# [18:16:28.578] de
# [18:16:28.451] lugar
# [18:16:28.426] algún
# [18:16:28.401] En
# [18:16:28.296] Some msg -> 284
