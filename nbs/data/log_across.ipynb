# %%
from pathlib import Path
from dutil.logger import Logger

# %%
nbs = '/'.join(find_dname().split('/')[:-2])
nbs
# Out:
# '/vic/dutil/nbs'

# %%
log = Logger('_bae17912', nbs+'/01_logger')

# %%
log('asd')

# %%
log.show()
# Out:
# [19:29:11.729] asd
# [19:19:02.455] Mancha
# [19:19:02.355] la
# [19:19:02.329] de
# [19:19:02.303] lugar
# [19:19:02.278] algún
# [19:19:02.252] En
# [19:19:02.133] Some msg 93
