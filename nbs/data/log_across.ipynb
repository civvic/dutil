# %%
from pathlib import Path
from dutil.logger import Logger

# %%
nbs = '/'.join(find_dname().split('/')[:-2])
nbs
# Out:
# '/vic/dutil/nbs'

# %%
log = Logger('_bae17912', nbs+'/01_logger')

# %%
log._s
# Out:
# '[20:11:11.522] Mancha\n[20:11:11.488] la\n[20:11:11.455] de\n[20:11:11.420] lugar\n[20:11:11.276] algún\n[20:11:11.248] En\n[20:11:11.142] Some msg -> 738\n'

# %%
log('asd')

# %%
log.show()
# Out:
# [20:11:45.291] asd
# [20:11:11.522] Mancha
# [20:11:11.488] la
# [20:11:11.455] de
# [20:11:11.420] lugar
# [20:11:11.276] algún
# [20:11:11.248] En
# [20:11:11.142] Some msg -> 738
