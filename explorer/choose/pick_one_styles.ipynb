# %%
import uuid
from IPython.display import HTML
from fasthtml.common import *
from monsterui.all import *
from dialoghelper import *

# %% [markdown]
# &read_url: Read url from web

# %% [markdown]
# Tools available from `dialoghelper`:
#
# - &`curr_dialog`: Get the current dialog info.
# - &`msg_idx`: Get absolute index of message in dialog.
# - &`add_html`: Send HTML to the browser to be swapped into the DOM using hx-swap-oob.
# - &`find_msg_id`: Get the current message id.
# - &`find_msgs`: Find messages in current specific dialog that contain the given information.
#   - (solveit can often get this id directly from its context, and will not need to use this if the required information is already available to it.)
# - &`read_msg`: Get the message indexed in the current dialog.
#   - To get the exact message use `n=0` and `relative=True` together with `msgid`.
#   - To get a relative message use `n` (relative position index).
#   - To get the nth message use `n` with `relative=False`, e.g `n=0` first message, `n=-1` last message.
# - &`del_msg`: Delete a message from the dialog.
# - &`add_msg`: Add/update a message to the queue to show after code execution completes.
# - &`update_msg`: Update an existing message.
# - &`url2note`: Read URL as markdown, and add a note below current message with the result
# - &`msg_insert_line`: Insert text at a specific location in a message.
# - &`msg_str_replace`: Find and replace text in a message.
# - &`msg_strs_replace`: Find and replace multiple strings in a message.
# - &`msg_replace_lines`: Replace a range of lines in a message with new content.
#   - Always first use `read_msg( msgid=msgid, n=0, relative=True, nums=True)` to view the content with line numbers.

# %%
url2note('https://raw.githubusercontent.com/AnswerDotAI/fasthtml/refs/heads/main/nbs/llms.txt')
url2note('https://raw.githubusercontent.com/AnswerDotAI/MonsterUI/refs/heads/main/docs/llms.txt')
# Out:
# ['_d655a371', '_159b28fa', '_473906a4', '_b419a249']

# %% [markdown]
# # FastHTML
#
# > FastHTML is a python library which brings together Starlette, Uvicorn, HTMX, and fastcore's `FT` "FastTags" into a library for creating server-rendered hypermedia applications. The `FastHTML` class itself inherits from `Starlette`, and adds decorator-based routing with many additions, Beforeware, automatic `FT` to HTML rendering, and much more.
#
# Things to remember when writing FastHTML apps:
#
# - Although parts of its API are inspired by FastAPI, it is *not* compatible with FastAPI syntax and is not targeted at creating API services
# - FastHTML includes support for Pico CSS and the fastlite sqlite library, although using both are optional; sqlalchemy can be used directly or via the fastsql library, and any CSS framework can be used. Support for the Surreal and css-scope-inline libraries are also included, but both are optional
# - FastHTML is compatible with JS-native web components and any vanilla JS library, but not with React, Vue, or Svelte
# - Use `serve()` for running uvicorn (`if __name__ == "__main__"` is not needed since it's automatic)
# - When a title is needed with a response, use `Titled`; note that that already wraps children in `Container`, and already includes both the meta title as well as the H1 element.

# %% [markdown]
# ## Docs
#
# - [FastHTML concise guide](https://www.fastht.ml/docs/ref/concise_guide.html.md): A brief overview of idiomatic FastHTML apps
# - [HTMX reference](https://raw.githubusercontent.com/bigskysoftware/htmx/master/www/content/reference.md): Brief description of all HTMX attributes, CSS classes, headers, events, extensions, js lib methods, and config options
# - [Starlette quick guide](https://gist.githubusercontent.com/jph00/e91192e9bdc1640f5421ce3c904f2efb/raw/61a2774912414029edaf1a55b506f0e283b93c46/starlette-quick.md): A quick overview of some Starlette features useful to FastHTML devs.

# %% [markdown]
# ## API
#
# - [API List](https://www.fastht.ml/docs/apilist.txt): A succint list of all functions and methods in fasthtml.
# - [MonsterUI API List](https://raw.githubusercontent.com/AnswerDotAI/MonsterUI/refs/heads/main/docs/apilist.txt): Complete API Reference for Monster UI, a component framework similar to shadcn, but for FastHTML

# %% [markdown]
# ## Examples
#
# - [Websockets application](https://raw.githubusercontent.com/AnswerDotAI/fasthtml/main/examples/basic_ws.py): Very brief example of using websockets with HTMX and FastHTML
# - [Todo list application](https://raw.githubusercontent.com/AnswerDotAI/fasthtml/main/examples/adv_app.py): Detailed walk-thru of a complete CRUD app in FastHTML showing idiomatic use of FastHTML and HTMX patterns.

# %% [markdown]
# ## Optional
#
# - [Surreal](https://raw.githubusercontent.com/AnswerDotAI/surreal/main/README.md): Tiny jQuery alternative for plain Javascript with inline Locality of Behavior, providing `me` and `any` functions
# - [Starlette full documentation](https://gist.githubusercontent.com/jph00/809e4a4808d4510be0e3dc9565e9cbd3/raw/9b717589ca44cedc8aaf00b2b8cacef922964c0f/starlette-sml.md): A subset of the Starlette documentation useful for FastHTML development.
# - [JS App Walkthrough](https://www.fastht.ml/docs/tutorials/e2e.html.md): An end-to-end walkthrough of a complete FastHTML app, including deployment to railway.
# - [FastHTML by Example](https://www.fastht.ml/docs/tutorials/by_example.html.md): A collection of 4 FastHTML apps showcasing idiomatic use of FastHTML and HTMX patterns.
# - [Using Jupyter to write FastHTML](https://www.fastht.ml/docs/tutorials/jupyter_and_fasthtml.html.md): A guide to developing FastHTML apps inside Jupyter notebooks.
# - [FT Components](https://www.fastht.ml/docs/explains/explaining_xt_components.html.md): Explanation of the `FT` components, which are a way to write HTML in a Pythonic way.
# - [FAQ](https://www.fastht.ml/docs/explains/faq.html.md): Answers to common questions about FastHTML.
# - [MiniDataAPI Spec](https://www.fastht.ml/docs/explains/minidataapi.html.md): Explanation of the MiniDataAPI specification, which allows us to use the same API for many different database engines.
# - [OAuth](https://www.fastht.ml/docs/explains/oauth.html.md): Tutorial and explanation of how to use OAuth in FastHTML apps.
# - [Routes](https://www.fastht.ml/docs/explains/routes.html.md): Explanation of how routes work in FastHTML.
# - [WebSockets](https://www.fastht.ml/docs/explains/websockets.html.md): Explanation of websockets and how they work in FastHTML.
# - [Custom Components](https://www.fastht.ml/docs/ref/defining_xt_component.md): Explanation of how to create custom components in FastHTML.
# - [Handling Handlers](https://www.fastht.ml/docs/ref/handlers.html.md): Explanation of how to request and response handlers work in FastHTML as routes.
# - [Live Reloading](https://www.fastht.ml/docs/ref/live_reload.html.md): Explanation of how to use live reloading for FastHTML development.

# %% [markdown]
# # MonsterUI Documentation
#
# > MonsterUI is a python library which brings styling to python for FastHTML apps.

# %% [markdown]
# ## API Reference
# - [API List](https://raw.githubusercontent.com/AnswerDotAI/MonsterUI/refs/heads/main/docs/apilist.txt): Complete API Reference

# %% [markdown]
# ## Examples
# - [Dashboard](https://monsterui.answer.ai/dashboard/md): FrankenUI Dashboard Example built with MonsterUI (original design by ShadCN)
# - [Forms](https://monsterui.answer.ai/forms/md): FrankenUI Forms Example built with MonsterUI (original design by ShadCN)
# - [Auth](https://monsterui.answer.ai/auth/md): FrankenUI Auth Example built with MonsterUI (original design by ShadCN)
# - [Mail](https://monsterui.answer.ai/mail/md): FrankenUI Mail Example built with MonsterUI (original design by ShadCN)
# - [Tasks](https://monsterui.answer.ai/tasks/md): FrankenUI Tasks Example built with MonsterUI (original design by ShadCN)
# - [Music](https://monsterui.answer.ai/music/md): FrankenUI Music Example build with MonsterUI (Original design by ShadCN)
# - [Scrollspy](https://monsterui.answer.ai/scrollspy/md): MonsterUI Scrollspy Example application
# - [Cards](https://monsterui.answer.ai/cards/md): FrankenUI Cards Example built with MonsterUI (original design by ShadCN)
# - [Ticket](https://monsterui.answer.ai/ticket/md): MonsterUI Help Desk Example - Professional Dashboard with DaisyUI components
# - [Playground](https://monsterui.answer.ai/playground/md): FrankenUI Playground Example built with MonsterUI (original design by ShadCN)

# %% [markdown]
# ## Optional
# - [Accordion | Link](https://monsterui.answer.ai/api_ref/docs_accordion_link/md): Accordion API Reference
# - [Button | Link](https://monsterui.answer.ai/api_ref/docs_button_link/md): Buttons & Links API Reference
# - [Cards](https://monsterui.answer.ai/api_ref/docs_cards/md): Cards API Reference
# - [Charts](https://monsterui.answer.ai/api_ref/docs_charts/md): Charts API Reference
# - [Containers](https://monsterui.answer.ai/api_ref/docs_containers/md): Articles, Containers & Sections API Reference
# - [Dividers](https://monsterui.answer.ai/api_ref/docs_dividers/md): Dividers API Reference
# - [Forms](https://monsterui.answer.ai/api_ref/docs_forms/md): Forms and User Inputs API Reference
# - [Html](https://monsterui.answer.ai/api_ref/docs_html/md): HTML Styling API Reference
# - [Icons | Images](https://monsterui.answer.ai/api_ref/docs_icons_images/md): Icons & Images API Reference
# - [Layout](https://monsterui.answer.ai/api_ref/docs_layout/md): Layout (Flex and Grid) API Reference
# - [Lightbox](https://monsterui.answer.ai/api_ref/docs_lightbox/md): Lightbox API Reference
# - [Lists](https://monsterui.answer.ai/api_ref/docs_lists/md): Lists API Reference
# - [Loading](https://monsterui.answer.ai/api_ref/docs_loading/md): Loading Indicators API Reference
# - [Markdown](https://monsterui.answer.ai/api_ref/docs_markdown/md): Markdown + automated HTML styling API Reference
# - [Modals](https://monsterui.answer.ai/api_ref/docs_modals/md): Modals API Reference
# - [Navigation](https://monsterui.answer.ai/api_ref/docs_navigation/md): Navigation (Nav, NavBar, Tabs, etc.) API Reference
# - [Notifications](https://monsterui.answer.ai/api_ref/docs_notifications/md): Alerts & Toasts API Reference
# - [Sliders](https://monsterui.answer.ai/api_ref/docs_sliders/md): Carousel Sliders API Reference
# - [Steps](https://monsterui.answer.ai/api_ref/docs_steps/md): Steps API Reference
# - [Tables](https://monsterui.answer.ai/api_ref/docs_tables/md): Tables API Reference
# - [Theme | Headers](https://monsterui.answer.ai/api_ref/docs_theme_headers/md): Theme and Headers API Reference
# - [Typography](https://monsterui.answer.ai/api_ref/docs_typography/md): Typography API Reference
# - [Layout](https://monsterui.answer.ai/tutorial_layout/md): MonsterUI Page Layout Guide
# - [Spacing](https://monsterui.answer.ai/tutorial_spacing/md): Padding & Margin & Spacing, Oh my! (MonsterUI Spacing Guide)

# %%
apply_classes??
# Out:
# Signature: apply_classes(html_str: str, class_map=None, class_map_mods=None) -> str
# Source:
# def apply_classes(html_str:str, # Html string
#                   class_map=None, # Class map
#                   class_map_mods=None # Class map that will modify the class map map (for small changes to base map)
#                  )->str: # Html string with classes applied
#     "Apply classes to html string"
#     if not html_str: return html_str
#     # Handles "Unicode strings with encoding declaration are not supported":
#     if html_str[:100].lstrip().startswith('<?xml'): html_str = html_str.split('?>', 1)[1].strip()
#     class_map = ifnone(class_map, franken_class_map)
#     if class_map_mods: class_map = {**class_map, **class_map_mods}
#     try:
#         html_str = html.fragment_fromstring(html_str, create_parent=True)
#         for selector, classes in class_map.items():
#             # Handle descendant selectors (e.g., 'pre code')
# ...

# %% [markdown]
# # Styling Problem: Widget Renderer
#
# **Goal**: Create a function to generate a FastHTML FT object that will be rendered inside the output area of code or prompt messages of a SolveIt dialog.
#
# The element contains a styled list of buttons with the following requirements:
#
# 1. **No bullets** - List items should not show bullet points
# 2. **Left-aligned text** - Button text should be aligned to the left inside each button
# 3. **Proper sizing** - Buttons should accommodate text without clipping
# 4. **Visual feedback** - Selected button should be visually distinct (primary style)
#
# **Tech stack**: FastHTML + MonsterUI

# %% [markdown]
# ## Function Signature
#
# ```python
# def _pick_one_ft(msgid, pickid, options, prompt_text, selected, active) -> FT:
#     """Generate a styled button list widget
#
#     Args:
#         msgid: Message ID for tracking
#         pickid: Unique picker ID for JavaScript interaction
#         options: List of option strings to display
#         prompt_text: Header text for the widget
#         selected: Index of selected option (or None)
#         active: If True, buttons are interactive; if False, disabled
#
#     Returns:
#         FT object (FastHTML component tree)
#     """
# ```
#
# Example: The function could return a `Div` containing a `Strong` header and a `Ul` list of buttons, but you can choose other element tree.

# %% [markdown]
# The basic problem you must solve: SolveIt process the HTML displayed in messages output and apply monsterui styles that can overwrite the original styles. Solve also apply different styles to output of code and prompt messages.
#
# For instance, the user run a code message:
#
# ```python
# _kw = {
#     'options': ['cytosine [C]', 'adenine [A]', 'thymine [T]'],
#     'prompt_text': 'Pick the nucleotide that is complementary to guanine [G]',
#     'active': True,
#     'selected': 0
# }
# pick_html = _pick_one_ft(msgid, pickid, **_kw)
# HTML((_id := find_msg_id()) + to_xml(pick_html))
# ```
#
# Or the user asks solveit in a prompt message to display the result of calling a tool that uses `_pick_one_ft`.

# %% [markdown]
# **List styling:**
# Lists can have various styles via `ListT` enum, but we need to avoid bullet styles.
#
# **Common pattern:**
# Use explicit classes and avoid relying solely on inline styles, as MonsterUI may add its own classes during rendering.

# %% [markdown]
# ## Current HTML Output vs Browser final HTML
#
# **What `_pick_one_ft` generates (example):**
#
# ```html
# <div data-pick-container="" data-msgid="_86971d98" data-pickid="bba5ebbb-4820-4297-b36c-3556b8eb75f3" data-selected="1" style="border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;">
# <strong class="font-bold ">Pick an option:</strong>  <ul style="padding: 0; margin-top: 10px; list-style: none;">
#     <li>
# <button onclick="selectPickOption('bba5ebbb-4820-4297-b36c-3556b8eb75f3', 0, 'e')" type="button" class="uk-btn uk-btn-default" style="width: 100%; text-align: left; opacity: 1;" data-orig-text="1. e">1. e</button>    </li>
#   </ul>
# </div>
# ```
#
# **What ends up in browser (after SolveIt post-transform, example):**
#
# ```html
# <div data-pick-container="" data-msgid="_44153ae2" data-pickid="5ed1c9a4-7965-4088-87bb-a37524e93e6f" data-selected="1" style="border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;">
# <strong class="font-bold ">It was the</strong>  <ul style="padding: 0; margin-top: 10px; list-style: none;" class="uk-list uk-list-bullet space-y-0">
#     <li class="leading-tight">
# <button onclick="selectPickOption('5ed1c9a4-7965-4088-87bb-a37524e93e6f', 0, 'best of times')" type="button" class="uk-btn uk-btn-default" style="width: 100%; text-align: left; opacity: 1;" data-orig-text="1. best of times">1. best of times</button>    </li>
#   </ul>
# </div>
# ```
#
# **Problems:**
# 1. `uk-list-bullet` class is added by MonsterUI, causing bullets to appear
# 2. Button text is not actually left-aligned despite `text-align: left` style
# 3. Long text may clip or wrap awkwardly
# 4. If the result of calling `_pick_one_ft(...) is displayed in the output area of a prompt message, It undergoes a different procedure than the cpde message.
#
# **List styling:**
# Lists can have various styles via `ListT` enum, but we need to avoid bullet styles.
#
# **Common pattern:**
# Use explicit classes and avoid relying solely on inline styles, as MonsterUI may add its own classes during rendering.

# %%
hdlr = Script("""
window.selectPickOption = function(pickid, optionIdx, optionText) {
    const container = document.querySelector(`[data-pickid="${pickid}"]`);
    if (!container) { console.error('Container not found for pickid:', pickid); return; }
    container.dataset.selected = optionIdx;
    container.querySelectorAll('button').forEach((btn, idx) => {
        btn.disabled = false;
        btn.style.opacity = '1';
        if (idx === optionIdx) { // Selected button: use primary style
            btn.classList.remove('uk-btn-default');
            btn.classList.add('uk-btn-primary');
            btn.textContent = `✓ ${optionIdx + 1}. ${optionText} (selected)`;
        } else { // Unselected buttons: use default style
            btn.classList.remove('uk-btn-primary');
            btn.classList.add('uk-btn-default');
            const origText = btn.dataset.origText || btn.textContent.replace(/^✓ /, '').replace(' (selected)', '');
            btn.dataset.origText = origText;
            btn.textContent = origText;
        }
    });
};
""")

show(hdlr)
# Out:
# <script>
# window.selectPickOption = function(pickid, optionIdx, optionText) {
#     const container = document.querySelector(`[data-pickid="${pickid}"]`);
#     if (!container) { console.error('Container not found for pickid:', pickid); return; }
#     container.dataset.selected = optionIdx;
#     container.querySelectorAll('button').forEach((btn, idx) => {
#         btn.disabled = false;
#         btn.style.opacity = '1';
#         if (idx === optionIdx) { // Selected button: use primary style
#             btn.classList.remove('uk-btn-default');
#             btn.classList.add('uk-btn-primary');
#             btn.textContent = `✓ ${optionIdx + 1}. ${optionText} (selected)`;
#         } else { // Unselected buttons: use default style
#             btn.classList.remove('uk-btn-primary');
#             btn.classList.add('uk-btn-default');
#             const origText = btn.dataset.origText || btn.textContent.replace(/^✓ /, '').replace(' (selected)', '');
# ...

# %%
# Current implementation (with styling issues)
def _pick_one_ft(msgid, pickid, options, prompt_text, selected, active) -> FT:
    btns = [
        Li(
            Button(
                f"{'✓ ' if selected==i else ''}{i+1}. {opt}{' (selected)' if selected==i else ''}",
                onclick=f"selectPickOption('{pickid}', {i}, '{opt}')" if active else None,
                disabled=not active and selected != i,
                cls=ButtonT.primary if selected==i else ButtonT.default,
                submit=False,
                style=f"width: 100%; text-align: left; opacity: {'1' if selected==i or active else '0.5'};"
            )
        ) for i, opt in enumerate(options)
    ]
    stl = "border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;"
    attrs = {
        'data-pick-container': True,
        'data-msgid': msgid,
        'data-pickid': pickid,
        'data-selected': selected if selected is not None else ''
    } if active else {}
    return Div(style=stl, **attrs)(
        Strong(prompt_text),
        Ul(*btns, style="padding: 0; margin-top: 10px; list-style: none;"),
    )

# %%
# Test harness
test_msgid = "test_msg_001"
test_pickid = str(uuid.uuid4())
test_options = ["First option", "Second option with much longer text contents Lorem ipsum dolor sit amet, consectetur adipiscing elit.", "Third"]
test_prompt = "Pick one:"

# Render with option 1 selected
widget = _pick_one_ft(test_msgid, test_pickid, test_options, test_prompt, selected=1, active=True)
show(widget)
# Out:
# <div data-pick-container data-msgid="test_msg_001" data-pickid="5dfaaed2-4cef-4528-adc0-e8b79007befd" data-selected="1" style="border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;">
# <strong class="font-bold ">Pick one:</strong>  <ul style="padding: 0; margin-top: 10px; list-style: none;">
#     <li>
# <button onclick="selectPickOption('5dfaaed2-4cef-4528-adc0-e8b79007befd', 0, 'First option')" type="button" class="uk-btn uk-btn-default" style="width: 100%; text-align: left; opacity: 1;">1. First option</button>    </li>
#     <li>
# ...

# %%
_id = add_msg(content='.', msg_type='prompt', output='.')
_id
# Out:
# '_4442dacc'

# %% [markdown]
# .
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# <div data-pick-container data-msgid="_4442dacc" data-pickid="cc4b9af5-0dda-4505-8f9a-4211f7e58530" data-selected="3" style="border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;">
# <strong class="font-bold ">It was the</strong>  <ul style="padding: 0; margin-top: 10px; list-style: none;">
#     <li>
# <button onclick="selectPickOption('cc4b9af5-0dda-4505-8f9a-4211f7e58530', 0, 'best of times')" type="button" class="uk-btn uk-btn-default" style="width: 100%; text-align: left; opacity: 1;">1. best of times</button>    </li>
#     <li>
# <button onclick="selectPickOption('cc4b9af5-0dda-4505-8f9a-4211f7e58530', 1, 'worst of times')" type="button" class="uk-btn uk-btn-default" style="width: 100%; text-align: left; opacity: 1;">2. worst of times</button>    </li>
#     <li>
# <button onclick="selectPickOption('cc4b9af5-0dda-4505-8f9a-4211f7e58530', 2, 'age of wisdom')" type="button" class="uk-btn uk-btn-default" style="width: 100%; text-align: left; opacity: 1;">3. age of wisdom</button>    </li>
#     <li>
# <button onclick="selectPickOption('cc4b9af5-0dda-4505-8f9a-4211f7e58530', 3, 'age of foolishness')" type="button" class="uk-btn uk-btn-primary" style="width: 100%; text-align: left; opacity: 1;">✓ 4. age of foolishness (selected)</button>    </li>
#   </ul>
# </div>

# %%
options = ['best of times', 'worst of times', 'age of wisdom', 'age of foolishness']
prompt_text = 'It was the'
_pid = str(uuid.uuid4())
pick_html = to_xml(_pick_one_ft(_id, _pid, options, prompt_text, selected=3, active=True))
_id = update_msg(msgid=_id, output=pick_html)
_id
# Out:
# '_4442dacc'

# %% [markdown]
# ## Goal

# %% [markdown]
# Fix the styling issues in `_pick_one_ft`:
#
# 1. Identify the core problem and how to overcome it. Ask for additional context if needed. Ask user for more examples, screenshots, run code.
# 2. Create a working function that:
#     - Prevent bullets from appearing on list items
#     - Ensure button text is truly left-aligned
#     - Make sure buttons properly accommodate text without clipping
#
# Use MonsterUI classes and patterns appropriately. Test the solution with the harness above.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Looking at this problem, I need to understand what's happening during the post-processing. The key issue is that SolveIt/MonsterUI is adding classes like `uk-list-bullet` to lists, which overrides our `list-style: none`.
#
# Let me first gather more information to understand the exact transformation:
#
# **Questions:**
#
# 1. **Can you show me a screenshot or describe visually what the current output looks like?** Specifically:
#    - Are bullets appearing despite `list-style: none`?
#    - Is the button text actually centered or right-aligned despite `text-align: left`?
#    - Are there any clipping issues with longer text?
#
# 2. **Can you run this diagnostic code** to help me see what classes/styles are being applied?
#
# ```python
# # Diagnostic: Let's see what happens with different list configurations
# from fasthtml.common import *
#
# test_cases = [
#     ("No class", Ul(Li("Item 1"), Li("Item 2"), style="list-style: none;")),
#     ("uk-list only", Ul(Li("Item 1"), Li("Item 2"), cls="uk-list", style="list-style: none;")),
#     ("uk-list uk-list-blank", Ul(Li("Item 1"), Li("Item 2"), cls="uk-list uk-list-blank")),
#     ("Div instead of Ul", Div(Div("Item 1"), Div("Item 2"), style="padding: 0; margin-top: 10px;")),
# ]
#
# for name, element in test_cases:
#     show(Div(Strong(name), element, style="margin: 20px 0; padding: 10px; border: 1px solid #ddd;"))
# ```
#
# 3. **Is there a difference** in how the output is processed between code message outputs vs prompt message outputs? You mentioned they undergo different procedures.
#
# **Initial hypothesis:**
#
# The problem seems to be that MonsterUI's post-processing is:
# - Adding `uk-list uk-list-bullet` classes to `<ul>` elements
# - Possibly overriding button text alignment with UIKit's default button styles
#
# **Potential solutions to test:**
#
# 1. **Use `uk-list-blank` explicitly** to prevent bullets
# 2. **Use a `Div` container instead of `Ul/Li`** to avoid list processing entirely
# 3. **Add `justify-content: flex-start` and `display: flex`** to buttons for proper left alignment
# 4. **Use MonsterUI's `UkList` component** with explicit styling
#
# Can you run the diagnostic code above and share what you see? That will help me create the right fix.

# %% [markdown]
# ![pasted_image_4a27606c-fe6c-4e64-b822-fe779911f60b.png](attachment:4a27606c-fe6c-4e64-b822-fe779911f60b)
#
# code message output
#
# ![pasted_image_afadc3e8-a61e-4fed-8bfc-44a6b9bcc766.png](attachment:afadc3e8-a61e-4fed-8bfc-44a6b9bcc766)
#
# prompt message output

# %%
# Diagnostic: Let's see what happens with different list configurations
test_cases = [
    ("No class", Ul(Li("Item 1"), Li("Item 2"), style="list-style: none;")),
    ("uk-list only", Ul(Li("Item 1"), Li("Item 2"), cls="uk-list", style="list-style: none;")),
    ("uk-list uk-list-blank", Ul(Li("Item 1"), Li("Item 2"), cls="uk-list uk-list-blank")),
    ("Div instead of Ul", Div(Div("Item 1"), Div("Item 2"), style="padding: 0; margin-top: 10px;")),
]

for name, element in test_cases:
    show(Div(Strong(name), element, style="margin: 20px 0; padding: 10px; border: 1px solid #ddd;"))
# Out:
# <div style="margin: 20px 0; padding: 10px; border: 1px solid #ddd;">
# <strong class="font-bold ">No class</strong>  <ul style="list-style: none;">
#     <li>Item 1</li>
#     <li>Item 2</li>
#   </ul>
# </div>
# <div style="margin: 20px 0; padding: 10px; border: 1px solid #ddd;">
# <strong class="font-bold ">uk-list only</strong>  <ul class="uk-list" style="list-style: none;">
#     <li>Item 1</li>
#     <li>Item 2</li>
#   </ul>
# </div>
# <div style="margin: 20px 0; padding: 10px; border: 1px solid #ddd;">
# <strong class="font-bold ">uk-list uk-list-blank</strong>  <ul class="uk-list uk-list-blank">
#     <li>Item 1</li>
#     <li>Item 2</li>
#   </ul>
# </div>
# <div style="margin: 20px 0; padding: 10px; border: 1px solid #ddd;">
# <strong class="font-bold ">Div instead of Ul</strong>  <div style="padding: 0; margin-top: 10px;">
#     <div>Item 1</div>
#     <div>Item 2</div>
#   </div>
# </div>

# %% [markdown]
# Rendered output in the browser:
# ```html
# <div class="uk-card-body p-1.5 pt-1 flex-col">
#       <div class="space-y-3"><div style="margin: 20px 0; padding: 10px; border: 1px solid #ddd;">
# <strong class="font-bold ">No class</strong>  <ul style="list-style: none;">
#     <li>Item 1</li>
#     <li>Item 2</li>
#   </ul>
# </div>
#
# <div style="margin: 20px 0; padding: 10px; border: 1px solid #ddd;">
# <strong class="font-bold ">uk-list only</strong>  <ul class="uk-list" style="list-style: none;">
#     <li>Item 1</li>
#     <li>Item 2</li>
#   </ul>
# </div>
#
# <div style="margin: 20px 0; padding: 10px; border: 1px solid #ddd;">
# <strong class="font-bold ">uk-list uk-list-blank</strong>  <ul class="uk-list uk-list-blank">
#     <li>Item 1</li>
#     <li>Item 2</li>
#   </ul>
# </div>
#
# <div style="margin: 20px 0; padding: 10px; border: 1px solid #ddd;">
# <strong class="font-bold ">Div instead of Ul</strong>  <div style="padding: 0; margin-top: 10px;">
#     <div>Item 1</div>
#     <div>Item 2</div>
#   </div>
# </div>
# </div>
#     </div>
# ```

# %% [markdown]
# .
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Perfect! Now I can see the issues clearly:
#
# **Problems identified from screenshots:**
#
# 1. **Bullets are appearing** in the prompt message output (white dots visible)
# 2. **Button text is centered**, not left-aligned despite `text-align: left`
# 3. **Text is clipping** - the long option shows "Lorem ipsum dolor sit amet, consectetur adipiscing elit. (selected)" is cut off
#
# **Good news from diagnostics:**
#
# The HTML in code message output is NOT being modified - no `uk-list-bullet` classes are being added. This means the issue is specifically with **button styling and how prompt messages are processed differently**.
#
# Let me check one more thing to understand the button alignment issue:
#
# ```python
# # Test button alignment approaches
# from fasthtml.common import *
#
# test_buttons = [
#     ("Default style", Button("Left aligned text", cls="uk-btn uk-btn-default", style="width: 100%; text-align: left;")),
#     ("With justify-start", Button("Left aligned text", cls="uk-btn uk-btn-default", style="width: 100%; justify-content: flex-start;")),
#     ("With flex + justify", Button("Left aligned text", cls="uk-btn uk-btn-default", style="width: 100%; display: flex; justify-content: flex-start;")),
#     ("With important", Button("Left aligned text", cls="uk-btn uk-btn-default", style="width: 100%; text-align: left !important;")),
# ]
#
# for name, btn in test_buttons:
#     show(Div(Strong(name), Div(btn, style="margin-top: 5px;"), style="margin: 10px 0; padding: 10px; border: 1px solid #ddd;"))
# ```
#
# Also, can you inspect one of the buttons in your browser's dev tools and share what computed styles are being applied to it? Specifically looking for `text-align`, `justify-content`, and `display` properties.

# %%
test_buttons = [
    ("Default style", Button("Left aligned text", cls="uk-btn uk-btn-default", style="width: 100%; text-align: left;")),
    ("With justify-start", Button("Left aligned text", cls="uk-btn uk-btn-default", style="width: 100%; justify-content: flex-start;")),
    ("With flex + justify", Button("Left aligned text", cls="uk-btn uk-btn-default", style="width: 100%; display: flex; justify-content: flex-start;")),
    ("With important", Button("Left aligned text", cls="uk-btn uk-btn-default", style="width: 100%; text-align: left !important;")),
]

for name, btn in test_buttons:
    show(Div(Strong(name), Div(btn, style="margin-top: 5px;"), style="margin: 10px 0; padding: 10px; border: 1px solid #ddd;"))
# Out:
# <div style="margin: 10px 0; padding: 10px; border: 1px solid #ddd;">
# <strong class="font-bold ">Default style</strong>  <div style="margin-top: 5px;">
# <button type="submit" class="uk-btn uk-btn uk-btn-default" style="width: 100%; text-align: left;">Left aligned text</button>  </div>
# </div>
# <div style="margin: 10px 0; padding: 10px; border: 1px solid #ddd;">
# <strong class="font-bold ">With justify-start</strong>  <div style="margin-top: 5px;">
# <button type="submit" class="uk-btn uk-btn uk-btn-default" style="width: 100%; justify-content: flex-start;">Left aligned text</button>  </div>
# </div>
# <div style="margin: 10px 0; padding: 10px; border: 1px solid #ddd;">
# <strong class="font-bold ">With flex + justify</strong>  <div style="margin-top: 5px;">
# <button type="submit" class="uk-btn uk-btn uk-btn-default" style="width: 100%; display: flex; justify-content: flex-start;">Left aligned text</button>  </div>
# </div>
# ...

# %% [markdown]
# ![pasted_image_72a4975c-87c0-4831-8b3a-4518b4f0409b.png](attachment:72a4975c-87c0-4831-8b3a-4518b4f0409b)
#
# ```html
# <div class="space-y-3"><div style="margin: 10px 0; padding: 10px; border: 1px solid #ddd;">
# <strong class="font-bold ">Default style</strong>  <div style="margin-top: 5px;">
# <button type="submit" class="uk-btn uk-btn uk-btn-default" style="width: 100%; text-align: left;">Left aligned text</button>  </div>
# </div>
#
# <div style="margin: 10px 0; padding: 10px; border: 1px solid #ddd;">
# <strong class="font-bold ">With justify-start</strong>  <div style="margin-top: 5px;">
# <button type="submit" class="uk-btn uk-btn uk-btn-default" style="width: 100%; justify-content: flex-start;">Left aligned text</button>  </div>
# </div>
#
# <div style="margin: 10px 0; padding: 10px; border: 1px solid #ddd;">
# <strong class="font-bold ">With flex + justify</strong>  <div style="margin-top: 5px;">
# <button type="submit" class="uk-btn uk-btn uk-btn-default" style="width: 100%; display: flex; justify-content: flex-start;">Left aligned text</button>  </div>
# </div>
#
# <div style="margin: 10px 0; padding: 10px; border: 1px solid #ddd;">
# <strong class="font-bold ">With important</strong>  <div style="margin-top: 5px;">
# <button type="submit" class="uk-btn uk-btn uk-btn-default" style="width: 100%; text-align: left !important;">Left aligned text</button>  </div>
# </div>
# </div>
# ```
#
# **Default style**:
# text-align: left
# text-align: left
# display: inline-flex

# %% [markdown]
# .
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Perfect! Now I can see the solution clearly:
#
# **Root cause:** UIKit buttons have `display: inline-flex` by default, which means `text-align: left` doesn't work. We need `justify-content: flex-start` to align flex content to the left.
#
# **The winning approach:** "With flex + justify" - using `display: flex; justify-content: flex-start;`
#
# Now let me address all three issues:
#
# 1. ✅ **Button alignment**: Use `display: flex; justify-content: flex-start;`
# 2. ✅ **Text clipping**: Add `white-space: normal; word-wrap: break-word;` to allow wrapping
# 3. ✅ **Bullets in prompt output**: Need to test if they appear with the current setup
#
# Let me create the fixed version:
#
# ```python
# def _pick_one_ft(msgid, pickid, options, prompt_text, selected, active) -> FT:
#     """Generate a styled button list widget
#
#     Args:
#         msgid: Message ID for tracking
#         pickid: Unique picker ID for JavaScript interaction
#         options: List of option strings to display
#         prompt_text: Header text for the widget
#         selected: Index of selected option (or None)
#         active: If True, buttons are interactive; if False, disabled
#
#     Returns:
#         FT object (FastHTML component tree)
#     """
#     btns = [
#         Li(
#             Button(
#                 f"{'✓ ' if selected==i else ''}{i+1}. {opt}{' (selected)' if selected==i else ''}",
#                 onclick=f"selectPickOption('{pickid}', {i}, '{opt}')" if active else None,
#                 disabled=not active and selected != i,
#                 cls=ButtonT.primary if selected==i else ButtonT.default,
#                 submit=False,
#                 style=f"width: 100%; display: flex; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; opacity: {'1' if selected==i or active else '0.5'};"
#             )
#         ) for i, opt in enumerate(options)
#     ]
#
#     stl = "border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;"
#     attrs = {
#         'data-pick-container': True,
#         'data-msgid': msgid,
#         'data-pickid': pickid,
#         'data-selected': selected if selected is not None else ''
#     } if active else {}
#
#     # Use explicit uk-list-blank class to prevent bullets
#     return Div(style=stl, **attrs)(
#         Strong(prompt_text),
#         Ul(*btns, cls="uk-list uk-list-blank", style="padding: 0; margin-top: 10px;"),
#     )
# ```
#
# Now let's test it:
#
# ```python
# # Test with the original test case
# test_msgid = "test_msg_002"
# test_pickid = str(uuid.uuid4())
# test_options = ["First option", "Second option with much longer text contents Lorem ipsum dolor sit amet, consectetur adipiscing elit.", "Third"]
# test_prompt = "Pick one:"
#
# widget = _pick_one_ft(test_msgid, test_pickid, test_options, test_prompt, selected=1, active=True)
# show(widget)
# ```
#
# Can you run this and check if:
# 1. The button text is now left-aligned ✓
# 2. Long text wraps properly instead of clipping ✓
# 3. No bullets appear (even in prompt message output) ✓

# %%
def _pick_one_ft(msgid, pickid, options, prompt_text, selected, active) -> FT:
    """Generate a styled button list widget
    
    Args:
        msgid: Message ID for tracking
        pickid: Unique picker ID for JavaScript interaction
        options: List of option strings to display
        prompt_text: Header text for the widget
        selected: Index of selected option (or None)
        active: If True, buttons are interactive; if False, disabled
    
    Returns:
        FT object (FastHTML component tree)
    """
    btns = [
        Li(
            Button(
                f"{'✓ ' if selected==i else ''}{i+1}. {opt}{' (selected)' if selected==i else ''}",
                onclick=f"selectPickOption('{pickid}', {i}, '{opt}')" if active else None,
                disabled=not active and selected != i,
                cls=ButtonT.primary if selected==i else ButtonT.default,
                submit=False,
                style=f"width: 100%; display: flex; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; opacity: {'1' if selected==i or active else '0.5'};"
            )
        ) for i, opt in enumerate(options)
    ]
    
    stl = "border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;"
    attrs = {
        'data-pick-container': True,
        'data-msgid': msgid,
        'data-pickid': pickid,
        'data-selected': selected if selected is not None else ''
    } if active else {}
    
    # Use explicit uk-list-blank class to prevent bullets
    return Div(style=stl, **attrs)(
        Strong(prompt_text),
        Ul(*btns, cls="uk-list uk-list-blank", style="padding: 0; margin-top: 10px;"),
    )

# %%
# Test with the original test case
test_msgid = "test_msg_002"
test_pickid = str(uuid.uuid4())
test_options = ["First option", "Second option with much longer text contents Lorem ipsum dolor sit amet, consectetur adipiscing elit.", "Third"]
# test_options = ["First option", "Second option with much longer text contents", "Third"]
test_prompt = "Pick one:"

widget = _pick_one_ft(test_msgid, test_pickid, test_options, test_prompt, selected=None, active=True)
show(widget)
# Out:
# <div data-pick-container data-msgid="test_msg_002" data-pickid="0d4ab4b7-e3cc-4815-9d86-504555b8b3f6" data-selected="" style="border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;">
# <strong class="font-bold ">Pick one:</strong>  <ul class="uk-list uk-list-blank" style="padding: 0; margin-top: 10px;">
#     <li>
# <button onclick="selectPickOption('0d4ab4b7-e3cc-4815-9d86-504555b8b3f6', 0, 'First option')" type="button" class="uk-btn uk-btn-default" style="width: 100%; display: flex; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; opacity: 1;">1. First option</button>    </li>
#     <li>
# ...

# %% [markdown]
# ![pasted_image_fcb5b4c3-2dfe-4224-97ae-414bba79ba37.png](attachment:fcb5b4c3-2dfe-4224-97ae-414bba79ba37)
#
# ![pasted_image_ed3131fa-2b60-4bbc-b75b-ffec0896c677.png](attachment:ed3131fa-2b60-4bbc-b75b-ffec0896c677)
#
# Alignment: solved.
#
# Text clipping/scrolling: fails when selected.
#
# The text styles are different if the option is selected: not bolded.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Good progress! Now I can see two remaining issues:
#
# 1. **Text clipping when selected** - The long text is getting cut off horizontally when the button is in the selected (primary) state
# 2. **Text style inconsistency** - Selected text should be bold to match the visual weight of the primary button style
#
# Let me investigate the clipping issue. It looks like when the button becomes primary, something is preventing the text from wrapping. Let me check:
#
# ```python
# # Compare primary vs default button rendering with long text
# test_long = "Second option with much longer text contents Lorem ipsum dolor sit amet, consectetur adipiscing elit."
#
# show(Div(
#     Strong("Default button (should wrap):"),
#     Button(f"2. {test_long}", cls="uk-btn uk-btn-default",
#            style="width: 100%; display: flex; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left;"),
#     style="margin: 10px; padding: 10px; border: 1px solid #ddd; max-width: 400px;"
# ))
#
# show(Div(
#     Strong("Primary button (check wrapping):"),
#     Button(f"✓ 2. {test_long} (selected)", cls="uk-btn uk-btn-primary",
#            style="width: 100%; display: flex; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left;"),
#     style="margin: 10px; padding: 10px; border: 1px solid #ddd; max-width: 400px;"
# ))
#
# show(Div(
#     Strong("Primary with font-weight:"),
#     Button(f"✓ 2. {test_long} (selected)", cls="uk-btn uk-btn-primary",
#            style="width: 100%; display: flex; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; font-weight: bold;"),
#     style="margin: 10px; padding: 10px; border: 1px solid #ddd; max-width: 400px;"
# ))
# ```
#
# Can you run this and share screenshots? I want to see if the primary button wraps correctly in isolation, or if there's something about the selection state change that's causing the issue.

# %%
# Compare primary vs default button rendering with long text
test_long = "Second option with much longer text contents Lorem ipsum dolor sit amet, consectetur adipiscing elit."

show(Div(
    Strong("Default button (should wrap):"),
    Button(f"2. {test_long}", cls="uk-btn uk-btn-default", 
           style="width: 100%; display: flex; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left;"),
    style="margin: 10px; padding: 10px; border: 1px solid #ddd; max-width: 400px;"
))

show(Div(
    Strong("Primary button (check wrapping):"),
    Button(f"✓ 2. {test_long} (selected)", cls="uk-btn uk-btn-primary", 
           style="width: 100%; display: flex; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left;"),
    style="margin: 10px; padding: 10px; border: 1px solid #ddd; max-width: 400px;"
))

show(Div(
    Strong("Primary with font-weight:"),
    Button(f"✓ 2. {test_long} (selected)", cls="uk-btn uk-btn-primary", 
           style="width: 100%; display: flex; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; font-weight: bold;"),
    style="margin: 10px; padding: 10px; border: 1px solid #ddd; max-width: 400px;"
))
# Out:
# <div style="margin: 10px; padding: 10px; border: 1px solid #ddd; max-width: 400px;">
# <strong class="font-bold ">Default button (should wrap):</strong><button type="submit" class="uk-btn uk-btn uk-btn-default" style="width: 100%; display: flex; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left;">2. Second option with much longer text contents Lorem ipsum dolor sit amet, consectetur adipiscing elit.</button></div>
# <div style="margin: 10px; padding: 10px; border: 1px solid #ddd; max-width: 400px;">
# <strong class="font-bold ">Primary button (check wrapping):</strong><button type="submit" class="uk-btn uk-btn uk-btn-primary" style="width: 100%; display: flex; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left;">✓ 2. Second option with much longer text contents Lorem ipsum dolor sit amet, consectetur adipiscing elit. (selected)</button></div>
# ...

# %% [markdown]
# ![pasted_image_f553aa56-cb9d-428b-ab22-bb9f7a1caceb.png](attachment:f553aa56-cb9d-428b-ab22-bb9f7a1caceb)
#
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Excellent! The buttons are wrapping correctly in isolation. This means **the clipping issue happens during the JavaScript state change**, not in the initial render.
#
# Looking at the JavaScript handler, I can see the problem:
#
# ```javascript
# btn.textContent = `✓ ${optionIdx + 1}. ${optionText} (selected)`;
# ```
#
# When JavaScript updates `textContent`, it's not preserving the styling properties. The issue is that the dynamic update might be triggering a re-layout.
#
# However, I notice something else: the buttons look good when rendered initially. The problem must be in how the widget is being used. Let me check - can you click on a button in the test widget and see if it clips after clicking?
#
# Also, I need to update the JavaScript to preserve the `data-orig-text` attribute properly. Let me create a complete fixed solution:
#
# ```python
# # Updated JavaScript handler with better text management
# hdlr_fixed = Script("""
# window.selectPickOption = function(pickid, optionIdx, optionText) {
#     const container = document.querySelector(`[data-pickid="${pickid}"]`);
#     if (!container) { console.error('Container not found for pickid:', pickid); return; }
#     container.dataset.selected = optionIdx;
#     container.querySelectorAll('button').forEach((btn, idx) => {
#         btn.disabled = false;
#         btn.style.opacity = '1';
#         // Preserve all inline styles
#         btn.style.display = 'flex';
#         btn.style.justifyContent = 'flex-start';
#         btn.style.whiteSpace = 'normal';
#         btn.style.wordWrap = 'break-word';
#         btn.style.textAlign = 'left';
#         btn.style.width = '100%';
#
#         if (idx === optionIdx) { // Selected button: use primary style
#             btn.classList.remove('uk-btn-default');
#             btn.classList.add('uk-btn-primary');
#             btn.style.fontWeight = 'bold';
#             const origText = btn.dataset.origText || btn.textContent.replace(/^✓ /, '').replace(' (selected)', '');
#             btn.dataset.origText = origText;
#             btn.textContent = `✓ ${origText} (selected)`;
#         } else { // Unselected buttons: use default style
#             btn.classList.remove('uk-btn-primary');
#             btn.classList.add('uk-btn-default');
#             btn.style.fontWeight = 'normal';
#             const origText = btn.dataset.origText || btn.textContent.replace(/^✓ /, '').replace(' (selected)', '');
#             btn.dataset.origText = origText;
#             btn.textContent = origText;
#         }
#     });
# };
# """)
#
# show(hdlr_fixed)
# ```
#
# And update the function to store original text and add font-weight:
#
# ```python
# def _pick_one_ft(msgid, pickid, options, prompt_text, selected, active) -> FT:
#     """Generate a styled button list widget
#
#     Args:
#         msgid: Message ID for tracking
#         pickid: Unique picker ID for JavaScript interaction
#         options: List of option strings to display
#         prompt_text: Header text for the widget
#         selected: Index of selected option (or None)
#         active: If True, buttons are interactive; if False, disabled
#
#     Returns:
#         FT object (FastHTML component tree)
#     """
#     btns = [
#         Li(
#             Button(
#                 f"{'✓ ' if selected==i else ''}{i+1}. {opt}{' (selected)' if selected==i else ''}",
#                 onclick=f"selectPickOption('{pickid}', {i}, '{opt}')" if active else None,
#                 disabled=not active and selected != i,
#                 cls=ButtonT.primary if selected==i else ButtonT.default,
#                 submit=False,
#                 data_orig_text=f"{i+1}. {opt}",  # Store original text for JS
#                 style=f"width: 100%; display: flex; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; font-weight: {'bold' if selected==i else 'normal'}; opacity: {'1' if selected==i or active else '0.5'};"
#             )
#         ) for i, opt in enumerate(options)
#     ]
#
#     stl = "border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;"
#     attrs = {
#         'data-pick-container': True,
#         'data-msgid': msgid,
#         'data-pickid': pickid,
#         'data-selected': selected if selected is not None else ''
#     } if active else {}
#
#     # Use explicit uk-list-blank class to prevent bullets
#     return Div(style=stl, **attrs)(
#         Strong(prompt_text),
#         Ul(*btns, cls="uk-list uk-list-blank", style="padding: 0; margin-top: 10px;"),
#     )
# ```
#
# Now test the complete solution:
#
# ```python
# # Test with interaction
# test_msgid = "test_msg_003"
# test_pickid = str(uuid.uuid4())
# test_options = ["First option", "Second option with much longer text contents Lorem ipsum dolor sit amet, consectetur adipiscing elit.", "Third"]
# test_prompt = "Pick one:"
#
# widget = _pick_one_ft(test_msgid, test_pickid, test_options, test_prompt, selected=1, active=True)
# show(widget)
# ```
#
# Try clicking between the buttons and see if the wrapping is preserved!

# %%
# Updated JavaScript handler with better text management
hdlr_fixed = Script("""
window.selectPickOption = function(pickid, optionIdx, optionText) {
    const container = document.querySelector(`[data-pickid="${pickid}"]`);
    if (!container) { console.error('Container not found for pickid:', pickid); return; }
    container.dataset.selected = optionIdx;
    container.querySelectorAll('button').forEach((btn, idx) => {
        btn.disabled = false;
        btn.style.opacity = '1';
        // Preserve all inline styles
        btn.style.display = 'flex';
        btn.style.justifyContent = 'flex-start';
        btn.style.whiteSpace = 'normal';
        btn.style.wordWrap = 'break-word';
        btn.style.textAlign = 'left';
        btn.style.width = '100%';
        
        if (idx === optionIdx) { // Selected button: use primary style
            btn.classList.remove('uk-btn-default');
            btn.classList.add('uk-btn-primary');
            btn.style.fontWeight = 'bold';
            const origText = btn.dataset.origText || btn.textContent.replace(/^✓ /, '').replace(' (selected)', '');
            btn.dataset.origText = origText;
            btn.textContent = `✓ ${origText} (selected)`;
        } else { // Unselected buttons: use default style
            btn.classList.remove('uk-btn-primary');
            btn.classList.add('uk-btn-default');
            btn.style.fontWeight = 'normal';
            const origText = btn.dataset.origText || btn.textContent.replace(/^✓ /, '').replace(' (selected)', '');
            btn.dataset.origText = origText;
            btn.textContent = origText;
        }
    });
};
""")

# %%
def _pick_one_ft(msgid, pickid, options, prompt_text, selected, active) -> FT:
    """Generate a styled button list widget
    
    Args:
        msgid: Message ID for tracking
        pickid: Unique picker ID for JavaScript interaction
        options: List of option strings to display
        prompt_text: Header text for the widget
        selected: Index of selected option (or None)
        active: If True, buttons are interactive; if False, disabled
    
    Returns:
        FT object (FastHTML component tree)
    """
    btns = [
        Li(
            Button(
                f"{'✓ ' if selected==i else ''}{i+1}. {opt}{' (selected)' if selected==i else ''}",
                onclick=f"selectPickOption('{pickid}', {i}, '{opt}')" if active else None,
                disabled=not active and selected != i,
                cls=ButtonT.primary if selected==i else ButtonT.default,
                submit=False,
                data_orig_text=f"{i+1}. {opt}",  # Store original text for JS
                style=f"width: 100%; display: flex; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; font-weight: {'bold' if selected==i else 'normal'}; opacity: {'1' if selected==i or active else '0.5'};"
            )
        ) for i, opt in enumerate(options)
    ]
    
    stl = "border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;"
    attrs = {
        'data-pick-container': True,
        'data-msgid': msgid,
        'data-pickid': pickid,
        'data-selected': selected if selected is not None else ''
    } if active else {}
    
    # Use explicit uk-list-blank class to prevent bullets
    return Div(style=stl, **attrs)(
        Strong(prompt_text),
        Ul(*btns, cls="uk-list uk-list-blank", style="padding: 0; margin-top: 10px;"),
    )

# %%
# Test with interaction
test_msgid = "test_msg_003"
test_pickid = str(uuid.uuid4())
test_options = ["First option", "Second option with much longer text contents Lorem ipsum dolor sit amet, consectetur adipiscing elit.", "Third"]
test_prompt = "Pick one:"

widget = _pick_one_ft(test_msgid, test_pickid, test_options, test_prompt, selected=None, active=True)
show(widget)
# Out:
# <div data-pick-container data-msgid="test_msg_003" data-pickid="9000da95-7013-4388-8a1c-861d82562ae6" data-selected="" style="border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;">
# <strong class="font-bold ">Pick one:</strong>  <ul class="uk-list uk-list-blank" style="padding: 0; margin-top: 10px;">
#     <li>
# <button onclick="selectPickOption('9000da95-7013-4388-8a1c-861d82562ae6', 0, 'First option')" data-orig-text="1. First option" type="button" class="uk-btn uk-btn-default" style="width: 100%; display: flex; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; font-weight: normal; opacity: 1;">1. First option</button>    </li>
#     <li>
# ...

# %% [markdown]
# ![pasted_image_656a1f86-b451-4f69-89cd-39d89476f288.png](attachment:656a1f86-b451-4f69-89cd-39d89476f288)
#
# See the attachment with mouse over bvefore clicking.
#
# Ok, when not selected, the text overflow. When selected the text is clipped. What should happen is the button height should adapt and grow if needed.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Ah! Now I see the real issue. The button text is **overflowing outside the button bounds** when not selected, and **clipping** when selected. The button needs to grow in height to accommodate the wrapped text.
#
# The problem is that flex buttons need explicit handling of text wrapping. Let me fix this:
#
# ```python
# # Updated JavaScript - ensure proper wrapping
# hdlr_fixed = Script("""
# window.selectPickOption = function(pickid, optionIdx, optionText) {
#     const container = document.querySelector(`[data-pickid="${pickid}"]`);
#     if (!container) { console.error('Container not found for pickid:', pickid); return; }
#     container.dataset.selected = optionIdx;
#     container.querySelectorAll('button').forEach((btn, idx) => {
#         btn.disabled = false;
#         btn.style.opacity = '1';
#         // Preserve all inline styles - key is flex-wrap and min-height
#         btn.style.display = 'flex';
#         btn.style.flexWrap = 'wrap';
#         btn.style.justifyContent = 'flex-start';
#         btn.style.whiteSpace = 'normal';
#         btn.style.wordWrap = 'break-word';
#         btn.style.textAlign = 'left';
#         btn.style.width = '100%';
#         btn.style.minHeight = 'fit-content';
#         btn.style.height = 'auto';
#
#         if (idx === optionIdx) { // Selected button: use primary style
#             btn.classList.remove('uk-btn-default');
#             btn.classList.add('uk-btn-primary');
#             btn.style.fontWeight = 'bold';
#             const origText = btn.dataset.origText || btn.textContent.replace(/^✓ /, '').replace(' (selected)', '');
#             btn.dataset.origText = origText;
#             btn.textContent = `✓ ${origText} (selected)`;
#         } else { // Unselected buttons: use default style
#             btn.classList.remove('uk-btn-primary');
#             btn.classList.add('uk-btn-default');
#             btn.style.fontWeight = 'normal';
#             const origText = btn.dataset.origText || btn.textContent.replace(/^✓ /, '').replace(' (selected)', '');
#             btn.dataset.origText = origText;
#             btn.textContent = origText;
#         }
#     });
# };
# """)
#
# show(hdlr_fixed)
# ```
#
# ```python
# def _pick_one_ft(msgid, pickid, options, prompt_text, selected, active) -> FT:
#     """Generate a styled button list widget
#
#     Args:
#         msgid: Message ID for tracking
#         pickid: Unique picker ID for JavaScript interaction
#         options: List of option strings to display
#         prompt_text: Header text for the widget
#         selected: Index of selected option (or None)
#         active: If True, buttons are interactive; if False, disabled
#
#     Returns:
#         FT object (FastHTML component tree)
#     """
#     btns = [
#         Li(
#             Button(
#                 f"{'✓ ' if selected==i else ''}{i+1}. {opt}{' (selected)' if selected==i else ''}",
#                 onclick=f"selectPickOption('{pickid}', {i}, '{opt}')" if active else None,
#                 disabled=not active and selected != i,
#                 cls=ButtonT.primary if selected==i else ButtonT.default,
#                 submit=False,
#                 data_orig_text=f"{i+1}. {opt}",  # Store original text for JS
#                 style=f"width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: {'bold' if selected==i else 'normal'}; opacity: {'1' if selected==i or active else '0.5'};"
#             )
#         ) for i, opt in enumerate(options)
#     ]
#
#     stl = "border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;"
#     attrs = {
#         'data-pick-container': True,
#         'data-msgid': msgid,
#         'data-pickid': pickid,
#         'data-selected': selected if selected is not None else ''
#     } if active else {}
#
#     # Use explicit uk-list-blank class to prevent bullets
#     return Div(style=stl, **attrs)(
#         Strong(prompt_text),
#         Ul(*btns, cls="uk-list uk-list-blank", style="padding: 0; margin-top: 10px;"),
#     )
# ```
#
# The key changes:
# 1. Added `flex-wrap: wrap` - allows content to wrap within flex container
# 2. Added `height: auto` - allows button to grow
# 3. Added `min-height: fit-content` - ensures button fits content
#
# Test it now:
#
# ```python
# # Test with interaction
# test_msgid = "test_msg_004"
# test_pickid = str(uuid.uuid4())
# test_options = ["First option", "Second option with much longer text contents Lorem ipsum dolor sit amet, consectetur adipiscing elit.", "Third"]
# test_prompt = "Pick one:"
#
# widget = _pick_one_ft(test_msgid, test_pickid, test_options, test_prompt, selected=None, active=True)
# show(widget)
# ```
#
# Click through the options and verify the button grows to fit the text!

# %%
# Updated JavaScript - ensure proper wrapping
hdlr_fixed = Script("""
window.selectPickOption = function(pickid, optionIdx, optionText) {
    const container = document.querySelector(`[data-pickid="${pickid}"]`);
    if (!container) { console.error('Container not found for pickid:', pickid); return; }
    container.dataset.selected = optionIdx;
    container.querySelectorAll('button').forEach((btn, idx) => {
        btn.disabled = false;
        btn.style.opacity = '1';
        // Preserve all inline styles - key is flex-wrap and min-height
        btn.style.display = 'flex';
        btn.style.flexWrap = 'wrap';
        btn.style.justifyContent = 'flex-start';
        btn.style.whiteSpace = 'normal';
        btn.style.wordWrap = 'break-word';
        btn.style.textAlign = 'left';
        btn.style.width = '100%';
        btn.style.minHeight = 'fit-content';
        btn.style.height = 'auto';
        
        if (idx === optionIdx) { // Selected button: use primary style
            btn.classList.remove('uk-btn-default');
            btn.classList.add('uk-btn-primary');
            btn.style.fontWeight = 'bold';
            const origText = btn.dataset.origText || btn.textContent.replace(/^✓ /, '').replace(' (selected)', '');
            btn.dataset.origText = origText;
            btn.textContent = `✓ ${origText} (selected)`;
        } else { // Unselected buttons: use default style
            btn.classList.remove('uk-btn-primary');
            btn.classList.add('uk-btn-default');
            btn.style.fontWeight = 'normal';
            const origText = btn.dataset.origText || btn.textContent.replace(/^✓ /, '').replace(' (selected)', '');
            btn.dataset.origText = origText;
            btn.textContent = origText;
        }
    });
};
""")

show(hdlr_fixed)
# Out:
# <script>
# window.selectPickOption = function(pickid, optionIdx, optionText) {
#     const container = document.querySelector(`[data-pickid="${pickid}"]`);
#     if (!container) { console.error('Container not found for pickid:', pickid); return; }
#     container.dataset.selected = optionIdx;
#     container.querySelectorAll('button').forEach((btn, idx) => {
#         btn.disabled = false;
#         btn.style.opacity = '1';
#         // Preserve all inline styles - key is flex-wrap and min-height
#         btn.style.display = 'flex';
#         btn.style.flexWrap = 'wrap';
#         btn.style.justifyContent = 'flex-start';
#         btn.style.whiteSpace = 'normal';
#         btn.style.wordWrap = 'break-word';
#         btn.style.textAlign = 'left';
#         btn.style.width = '100%';
#         btn.style.minHeight = 'fit-content';
#         btn.style.height = 'auto';
#
#         if (idx === optionIdx) { // Selected button: use primary style
# ...

# %%
def _pick_one_ft(msgid, pickid, options, prompt_text, selected, active) -> FT:
    """Generate a styled button list widget
    
    Args:
        msgid: Message ID for tracking
        pickid: Unique picker ID for JavaScript interaction
        options: List of option strings to display
        prompt_text: Header text for the widget
        selected: Index of selected option (or None)
        active: If True, buttons are interactive; if False, disabled
    
    Returns:
        FT object (FastHTML component tree)
    """
    btns = [
        Li(
            Button(
                f"{'✓ ' if selected==i else ''}{i+1}. {opt}{' (selected)' if selected==i else ''}",
                onclick=f"selectPickOption('{pickid}', {i}, '{opt}')" if active else None,
                disabled=not active and selected != i,
                cls=ButtonT.primary if selected==i else ButtonT.default,
                submit=False,
                data_orig_text=f"{i+1}. {opt}",  # Store original text for JS
                style=f"width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: {'bold' if selected==i else 'normal'}; opacity: {'1' if selected==i or active else '0.5'};"
            )
        ) for i, opt in enumerate(options)
    ]
    
    stl = "border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;"
    attrs = {
        'data-pick-container': True,
        'data-msgid': msgid,
        'data-pickid': pickid,
        'data-selected': selected if selected is not None else ''
    } if active else {}
    
    # Use explicit uk-list-blank class to prevent bullets
    return Div(style=stl, **attrs)(
        Strong(prompt_text),
        Ul(*btns, cls="uk-list uk-list-blank", style="padding: 0; margin-top: 10px;"),
    )

# %%
# Test with interaction
test_msgid = "test_msg_004"
test_pickid = str(uuid.uuid4())
test_options = ["First option", "Second option with much longer text contents Lorem ipsum dolor sit amet, consectetur adipiscing elit.", "Third"]
test_prompt = "Pick one:"

widget = _pick_one_ft(test_msgid, test_pickid, test_options, test_prompt, selected=None, active=True)
show(widget)
# Out:
# <div data-pick-container data-msgid="test_msg_004" data-pickid="e864cd31-bd90-48c9-9523-20988cf5f9fc" data-selected="" style="border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;">
# <strong class="font-bold ">Pick one:</strong>  <ul class="uk-list uk-list-blank" style="padding: 0; margin-top: 10px;">
#     <li>
# <button onclick="selectPickOption('e864cd31-bd90-48c9-9523-20988cf5f9fc', 0, 'First option')" data-orig-text="1. First option" type="button" class="uk-btn uk-btn-default" style="width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: normal; opacity: 1;">1. First option</button>    </li>
#     <li>
# ...

# %% [markdown]
# Ok, that's it. Now works as expected. We'll refine later.
#
# Now the much harder problem, what's happens if the output is for in a prompt message. Prepare a test harness looking at my example some messages above.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Perfect! Glad the styling is working now. Let's tackle the prompt message output issue.
#
# Looking back at your earlier example, I need to create a test harness that simulates what happens when the widget is displayed in a **prompt message output** (where different post-processing occurs).
#
# Here's my test harness:
#
# ```python
# # Test harness for prompt message output
# # This simulates calling the function from a tool or displaying it as prompt output
#
# def test_prompt_output():
#     """Simulate displaying widget in prompt message output"""
#     test_msgid = "_prompt_test_001"
#     test_pickid = str(uuid.uuid4())
#     test_options = [
#         'best of times',
#         'worst of times',
#         'age of wisdom',
#         'age of foolishness with some longer text to test wrapping behavior'
#     ]
#     test_prompt = 'It was the'
#
#     # Generate widget
#     widget = _pick_one_ft(test_msgid, test_pickid, test_options, test_prompt, selected=3, active=True)
#
#     # Convert to XML (as would happen in tool output)
#     widget_html = to_xml(widget)
#
#     print("Generated HTML:")
#     print(widget_html)
#     print("\n" + "="*80 + "\n")
#
#     # Create a prompt message and update its output
#     msg_id = add_msg(content='Display the widget', msg_type='prompt', output=widget_html)
#
#     return msg_id, test_pickid
#
# # Run test
# msg_id, pickid = test_prompt_output()
# print(f"Created prompt message: {msg_id}")
# print(f"Picker ID: {pickid}")
# ```
#
# This will:
# 1. Create a widget with selected option
# 2. Convert it to HTML (as tool output would)
# 3. Add it as a prompt message output
# 4. Show us what gets rendered
#
# Can you run this and share:
# 1. A screenshot of how it renders
# 2. What issues you see (bullets? alignment? clipping?)
# 3. The final HTML from browser inspector if possible
#
# This will help me understand what additional transformations are happening to prompt message outputs.

# %%
# Test harness for prompt message output
# This simulates calling the function from a tool or displaying it as prompt output

def test_prompt_output():
    """Simulate displaying widget in prompt message output"""
    test_msgid = "_prompt_test_001"
    test_pickid = str(uuid.uuid4())
    test_options = [
        'best of times', 
        'worst of times', 
        'age of wisdom', 
        'age of foolishness with some longer text to test wrapping behavior'
    ]
    test_prompt = 'It was the'
    
    # Generate widget
    widget = _pick_one_ft(test_msgid, test_pickid, test_options, test_prompt, selected=3, active=True)
    
    # Convert to XML (as would happen in tool output)
    widget_html = to_xml(widget)
    
    print("Generated HTML:")
    print(widget_html)
    print("\n" + "="*80 + "\n")
    
    # Create a prompt message and update its output
    msg_id = add_msg(content='Display the widget', msg_type='prompt', output=widget_html)
    
    return msg_id, test_pickid

# Run test
msg_id, pickid = test_prompt_output()
print(f"Created prompt message: {msg_id}")
print(f"Picker ID: {pickid}")
# Out:
# Generated HTML:
# <div data-pick-container data-msgid="_prompt_test_001" data-pickid="ab152da3-9b00-4f96-b728-48db4f4b8f6a" data-selected="3" style="border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;">
# <strong class="font-bold ">It was the</strong>  <ul class="uk-list uk-list-blank" style="padding: 0; margin-top: 10px;">
#     <li>
# <button onclick="selectPickOption('ab152da3-9b00-4f96-b728-48db4f4b8f6a', 0, 'best of times')" data-orig-text="1. best of times" type="button" class="uk-btn uk-btn-default" style="width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: normal; opacity: 1;">1. best of times</button>    </li>
#     <li>
# ...

# %% [markdown]
# Display the widget
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# <div data-pick-container data-msgid="_prompt_test_001" data-pickid="ab152da3-9b00-4f96-b728-48db4f4b8f6a" data-selected="3" style="border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;">
# <strong class="font-bold ">It was the</strong>  <ul class="uk-list uk-list-blank" style="padding: 0; margin-top: 10px;">
#     <li>
# <button onclick="selectPickOption('ab152da3-9b00-4f96-b728-48db4f4b8f6a', 0, 'best of times')" data-orig-text="1. best of times" type="button" class="uk-btn uk-btn-default" style="width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: normal; opacity: 1;">1. best of times</button>    </li>
#     <li>
# <button onclick="selectPickOption('ab152da3-9b00-4f96-b728-48db4f4b8f6a', 1, 'worst of times')" data-orig-text="2. worst of times" type="button" class="uk-btn uk-btn-default" style="width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: normal; opacity: 1;">2. worst of times</button>    </li>
#     <li>
# <button onclick="selectPickOption('ab152da3-9b00-4f96-b728-48db4f4b8f6a', 2, 'age of wisdom')" data-orig-text="3. age of wisdom" type="button" class="uk-btn uk-btn-default" style="width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: normal; opacity: 1;">3. age of wisdom</button>    </li>
#     <li>
# <button onclick="selectPickOption('ab152da3-9b00-4f96-b728-48db4f4b8f6a', 3, 'age of foolishness with some longer text to test wrapping behavior')" data-orig-text="4. age of foolishness with some longer text to test wrapping behavior" type="button" class="uk-btn uk-btn-primary" style="width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: bold; opacity: 1;">✓ 4. age of foolishness with some longer text to test wrapping behavior (selected)</button>    </li>
#   </ul>
# </div>

# %% [markdown]
# ![pasted_image_0ca5fb81-17c9-48f5-91aa-dff3f95e9632.png](attachment:0ca5fb81-17c9-48f5-91aa-dff3f95e9632)
#
# The bullets are back.
#
#
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# You're right! The bullets are back in the prompt message output. This confirms that prompt messages undergo different post-processing than code messages.
#
# Looking at the screenshot, despite us explicitly setting `uk-list-blank`, the system is adding `uk-list-bullet` class (or similar) during post-processing.
#
# Let me check what's happening in the browser inspector. Can you:
#
# 1. **Inspect the `<ul>` element** in the prompt output and share what classes it has?
# 2. **Check if there's a difference** between the HTML we generated vs what's in the DOM?
#
# Meanwhile, let me try a different approach - using `!important` to force the list style, or avoiding `<ul>` entirely:
#
# ```python
# # Test 1: Force list-style with !important
# def test_list_styles():
#     """Test different approaches to prevent bullets"""
#
#     test_cases = [
#         ("Current (uk-list-blank)",
#          Ul(Li("Item 1"), Li("Item 2"), cls="uk-list uk-list-blank", style="padding: 0; margin-top: 10px;")),
#
#         ("With !important",
#          Ul(Li("Item 1"), Li("Item 2"), cls="uk-list uk-list-blank", style="padding: 0; margin-top: 10px; list-style: none !important;")),
#
#         ("Div container instead of Ul",
#          Div(Div("Item 1"), Div("Item 2"), style="padding: 0; margin-top: 10px;")),
#
#         ("Ul with inline list-style override",
#          Ul(Li("Item 1", style="list-style: none;"), Li("Item 2", style="list-style: none;"),
#             cls="uk-list uk-list-blank", style="padding: 0; margin-top: 10px; list-style-type: none !important;")),
#     ]
#
#     msg_ids = []
#     for name, element in test_cases:
#         html = to_xml(Div(Strong(name), element, style="margin: 20px 0; padding: 10px; border: 1px solid #ddd;"))
#         msg_id = add_msg(content=f'Test: {name}', msg_type='prompt', output=html)
#         msg_ids.append((name, msg_id))
#
#     return msg_ids
#
# # Run tests
# test_results = test_list_styles()
# for name, msg_id in test_results:
#     print(f"{name}: {msg_id}")
# ```
#
# Run this and let's see which approach successfully prevents bullets in prompt message outputs!

# %% [markdown]
# ```html
# <ul class="uk-list uk-list-blank uk-list uk-list-bullet space-y-0" style="padding: 0; margin-top: 10px;">
#     <li class="leading-tight">
# <button onclick="selectPickOption('ab152da3-9b00-4f96-b728-48db4f4b8f6a', 0, 'best of times')" data-orig-text="1. best of times" type="button" class="uk-btn uk-btn-default" style="width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; overflow-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: normal; opacity: 1;">1. best of times</button>    </li>
# ...
#   </ul>
# ```
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Perfect! Now I can see the problem clearly:
#
# **The post-processor is adding:**
# - `uk-list uk-list-bullet` (duplicate `uk-list` + the bullet class)
# - `space-y-0`
# - `leading-tight` on `<li>` elements
#
# Even though we explicitly set `uk-list-blank`, it's being overridden by `uk-list-bullet` added later.
#
# **Solution approaches:**
#
# 1. **Use `!important`** to force override
# 2. **Use `Div` instead of `Ul`** to avoid list processing entirely
# 3. **Add inline styles to `<li>` elements** to override bullets
#
# Let me test which works:
#
# ```python
# # Test different approaches to prevent bullets in prompt output
# def test_bullet_prevention():
#     """Test approaches to prevent bullets in prompt message output"""
#
#     test_pickid = str(uuid.uuid4())
#
#     # Approach 1: !important on list-style
#     widget1 = Div(style="border: 1px solid #ccc; padding: 10px; margin: 10px 0;")(
#         Strong("Approach 1: !important"),
#         Ul(
#             Li(Button("Option 1", cls="uk-btn uk-btn-default", style="width: 100%;")),
#             Li(Button("Option 2", cls="uk-btn uk-btn-primary", style="width: 100%;")),
#             cls="uk-list uk-list-blank",
#             style="padding: 0; margin-top: 10px; list-style: none !important; list-style-type: none !important;"
#         )
#     )
#
#     # Approach 2: Div container instead of Ul/Li
#     widget2 = Div(style="border: 1px solid #ccc; padding: 10px; margin: 10px 0;")(
#         Strong("Approach 2: Div container"),
#         Div(
#             Div(Button("Option 1", cls="uk-btn uk-btn-default", style="width: 100%; margin-bottom: 5px;")),
#             Div(Button("Option 2", cls="uk-btn uk-btn-primary", style="width: 100%; margin-bottom: 5px;")),
#             style="padding: 0; margin-top: 10px;"
#         )
#     )
#
#     # Approach 3: Inline styles on Li elements
#     widget3 = Div(style="border: 1px solid #ccc; padding: 10px; margin: 10px 0;")(
#         Strong("Approach 3: Li inline styles"),
#         Ul(
#             Li(Button("Option 1", cls="uk-btn uk-btn-default", style="width: 100%;"),
#                style="list-style: none !important; list-style-type: none !important;"),
#             Li(Button("Option 2", cls="uk-btn uk-btn-primary", style="width: 100%;"),
#                style="list-style: none !important; list-style-type: none !important;"),
#             cls="uk-list uk-list-blank",
#             style="padding: 0; margin-top: 10px; list-style: none !important;"
#         )
#     )
#
#     # Create prompt messages for each
#     msg1 = add_msg(content='Test 1', msg_type='prompt', output=to_xml(widget1))
#     msg2 = add_msg(content='Test 2', msg_type='prompt', output=to_xml(widget2))
#     msg3 = add_msg(content='Test 3', msg_type='prompt', output=to_xml(widget3))
#
#     return msg1, msg2, msg3
#
# # Run tests
# msg1, msg2, msg3 = test_bullet_prevention()
# print(f"Created test messages: {msg1}, {msg2}, {msg3}")
# ```
#
# Run this and share screenshots of all three approaches. My guess is **Approach 2 (Div container)** will work best since it completely avoids the list processing pipeline.

# %%
# Test different approaches to prevent bullets in prompt output
def test_bullet_prevention():
    """Test approaches to prevent bullets in prompt message output"""
    
    test_pickid = str(uuid.uuid4())
    
    # Approach 1: !important on list-style
    widget1 = Div(style="border: 1px solid #ccc; padding: 10px; margin: 10px 0;")(
        Strong("Approach 1: !important"),
        Ul(
            Li(Button("Option 1", cls="uk-btn uk-btn-default", style="width: 100%;")),
            Li(Button("Option 2", cls="uk-btn uk-btn-primary", style="width: 100%;")),
            cls="uk-list uk-list-blank",
            style="padding: 0; margin-top: 10px; list-style: none !important; list-style-type: none !important;"
        )
    )
    
    # Approach 2: Div container instead of Ul/Li
    widget2 = Div(style="border: 1px solid #ccc; padding: 10px; margin: 10px 0;")(
        Strong("Approach 2: Div container"),
        Div(
            Div(Button("Option 1", cls="uk-btn uk-btn-default", style="width: 100%; margin-bottom: 5px;")),
            Div(Button("Option 2", cls="uk-btn uk-btn-primary", style="width: 100%; margin-bottom: 5px;")),
            style="padding: 0; margin-top: 10px;"
        )
    )
    
    # Approach 3: Inline styles on Li elements
    widget3 = Div(style="border: 1px solid #ccc; padding: 10px; margin: 10px 0;")(
        Strong("Approach 3: Li inline styles"),
        Ul(
            Li(Button("Option 1", cls="uk-btn uk-btn-default", style="width: 100%;"), 
               style="list-style: none !important; list-style-type: none !important;"),
            Li(Button("Option 2", cls="uk-btn uk-btn-primary", style="width: 100%;"),
               style="list-style: none !important; list-style-type: none !important;"),
            cls="uk-list uk-list-blank",
            style="padding: 0; margin-top: 10px; list-style: none !important;"
        )
    )
    
    # Create prompt messages for each
    msg1 = add_msg(content='Test 1', msg_type='prompt', output=to_xml(widget1))
    msg2 = add_msg(content='Test 2', msg_type='prompt', output=to_xml(widget2))
    msg3 = add_msg(content='Test 3', msg_type='prompt', output=to_xml(widget3))
    
    return msg1, msg2, msg3

# Run tests
msg1, msg2, msg3 = test_bullet_prevention()
print(f"Created test messages: {msg1}, {msg2}, {msg3}")
# Out:
# Created test messages: _c220828e, _e8ba524b, _de1af23e

# %% [markdown]
# Test 1
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# <div style="border: 1px solid #ccc; padding: 10px; margin: 10px 0;">
# <strong class="font-bold ">Approach 1: !important</strong>  <ul class="uk-list uk-list-blank" style="padding: 0; margin-top: 10px; list-style: none !important; list-style-type: none !important;">
#     <li>
# <button type="submit" class="uk-btn uk-btn uk-btn-default" style="width: 100%;">Option 1</button>    </li>
#     <li>
# <button type="submit" class="uk-btn uk-btn uk-btn-primary" style="width: 100%;">Option 2</button>    </li>
#   </ul>
# </div>

# %% [markdown]
# Test 2
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# <div style="border: 1px solid #ccc; padding: 10px; margin: 10px 0;">
# <strong class="font-bold ">Approach 2: Div container</strong>  <div style="padding: 0; margin-top: 10px;">
#     <div>
# <button type="submit" class="uk-btn uk-btn uk-btn-default" style="width: 100%; margin-bottom: 5px;">Option 1</button>    </div>
#     <div>
# <button type="submit" class="uk-btn uk-btn uk-btn-primary" style="width: 100%; margin-bottom: 5px;">Option 2</button>    </div>
#   </div>
# </div>

# %% [markdown]
# Test 3
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# <div style="border: 1px solid #ccc; padding: 10px; margin: 10px 0;">
# <strong class="font-bold ">Approach 3: Li inline styles</strong>  <ul class="uk-list uk-list-blank" style="padding: 0; margin-top: 10px; list-style: none !important;">
#     <li style="list-style: none !important; list-style-type: none !important;">
# <button type="submit" class="uk-btn uk-btn uk-btn-default" style="width: 100%;">Option 1</button>    </li>
#     <li style="list-style: none !important; list-style-type: none !important;">
# <button type="submit" class="uk-btn uk-btn uk-btn-primary" style="width: 100%;">Option 2</button>    </li>
#   </ul>
# </div>

# %% [markdown]
# # v1

# %% [markdown]
# Div container it is!
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Perfect! **Approach 2 (Div container)** wins! No bullets at all since it completely bypasses the list processing.
#
# Now let's update `_pick_one_ft` to use `Div` containers instead of `Ul/Li`:
#
# ```python
# def _pick_one_ft(msgid, pickid, options, prompt_text, selected, active) -> FT:
#     """Generate a styled button list widget
#
#     Args:
#         msgid: Message ID for tracking
#         pickid: Unique picker ID for JavaScript interaction
#         options: List of option strings to display
#         prompt_text: Header text for the widget
#         selected: Index of selected option (or None)
#         active: If True, buttons are interactive; if False, disabled
#
#     Returns:
#         FT object (FastHTML component tree)
#     """
#     btns = [
#         Div(
#             Button(
#                 f"{'✓ ' if selected==i else ''}{i+1}. {opt}{' (selected)' if selected==i else ''}",
#                 onclick=f"selectPickOption('{pickid}', {i}, '{opt}')" if active else None,
#                 disabled=not active and selected != i,
#                 cls=ButtonT.primary if selected==i else ButtonT.default,
#                 submit=False,
#                 data_orig_text=f"{i+1}. {opt}",  # Store original text for JS
#                 style=f"width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: {'bold' if selected==i else 'normal'}; opacity: {'1' if selected==i or active else '0.5'};"
#             ),
#             style="margin-bottom: 5px;"  # Spacing between buttons
#         ) for i, opt in enumerate(options)
#     ]
#
#     stl = "border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;"
#     attrs = {
#         'data-pick-container': True,
#         'data-msgid': msgid,
#         'data-pickid': pickid,
#         'data-selected': selected if selected is not None else ''
#     } if active else {}
#
#     # Use Div container instead of Ul to avoid bullet processing
#     return Div(style=stl, **attrs)(
#         Strong(prompt_text),
#         Div(*btns, style="padding: 0; margin-top: 10px;"),
#     )
# ```
#
# Now let's test it in both code and prompt message outputs:
#
# ```python
# # Test in code message (should still work)
# test_msgid = "test_final_code"
# test_pickid = str(uuid.uuid4())
# test_options = ["Short", "Second option with much longer text contents Lorem ipsum dolor sit amet, consectetur adipiscing elit.", "Third"]
# test_prompt = "Code output test:"
#
# widget = _pick_one_ft(test_msgid, test_pickid, test_options, test_prompt, selected=1, active=True)
# show(widget)
# ```
#
# ```python
# # Test in prompt message (the hard case)
# test_msgid = "_final_prompt_test"
# test_pickid = str(uuid.uuid4())
# test_options = [
#     'best of times',
#     'worst of times',
#     'age of wisdom',
#     'age of foolishness with some longer text to test wrapping behavior'
# ]
# test_prompt = 'Final test - It was the'
#
# widget = _pick_one_ft(test_msgid, test_pickid, test_options, test_prompt, selected=3, active=True)
# msg_id = add_msg(content='Final prompt test', msg_type='prompt', output=to_xml(widget))
# print(f"Created prompt message: {msg_id}")
# ```
#
# Run both tests and verify:
# - ✅ No bullets in either output
# - ✅ Text is left-aligned
# - ✅ Long text wraps properly
# - ✅ Buttons are interactive

# %%
def _pick_one_ft(msgid, pickid, options, prompt_text, selected, active) -> FT:
    """Generate a styled button list widget
    
    Args:
        msgid: Message ID for tracking
        pickid: Unique picker ID for JavaScript interaction
        options: List of option strings to display
        prompt_text: Header text for the widget
        selected: Index of selected option (or None)
        active: If True, buttons are interactive; if False, disabled
    
    Returns:
        FT object (FastHTML component tree)
    """

    # At the start of _pick_one_ft, before creating btns:
    # Calculate a stable width - find longest option text
    max_opt_len = max(len(f"{i+1}. {opt} (selected)") for i, opt in enumerate(options))
    # Use ch units (character width) for more predictable sizing
    min_width = min(max_opt_len * 0.6, 40)  # Cap at reasonable size

    btns = [
        Div(
            Button(
                f"{'✓ ' if selected==i else ''}{i+1}. {opt}{' (selected)' if selected==i else ''}",
                onclick=f"selectPickOption('{pickid}', {i}, '{opt}')" if active else None,
                disabled=not active and selected != i,
                cls=ButtonT.primary if selected==i else ButtonT.default,
                submit=False,
                data_orig_text=f"{i+1}. {opt}",  # Store original text for JS
                style=f"width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: {'bold' if selected==i else 'normal'}; opacity: {'1' if selected==i or active else '0.5'};"
            ),
            style="margin-bottom: 5px;"  # Spacing between buttons
        ) for i, opt in enumerate(options)
    ]
    
    # stl = "border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;"
    # stl = "border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 60%; width: fit-content;"
    # stl = "border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 60%; min-width: min-content;"
    stl = f"border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 60%; min-width: {min_width}ch;"

    attrs = {
        'data-pick-container': True,
        'data-msgid': msgid,
        'data-pickid': pickid,
        'data-selected': selected if selected is not None else ''
    } if active else {}
    
    # Use Div container instead of Ul to avoid bullet processing
    return Div(style=stl, **attrs)(
        Strong(prompt_text),
        Div(*btns, style="padding: 0; margin-top: 10px;"),
    )

# %%
# Test in code message (should still work)
test_msgid = "test_final_code"
test_pickid = str(uuid.uuid4())
test_options = ["Short", "Second option with much longer text contents Lorem ipsum dolor sit amet, consectetur adipiscing elit.", "Third"]
test_prompt = "Code output test:"

widget = _pick_one_ft(test_msgid, test_pickid, test_options, test_prompt, selected=1, active=True)
show(widget)
# Out:
# <div data-pick-container data-msgid="test_final_code" data-pickid="d50eaa68-5d39-44ce-b338-a83b8c89e880" data-selected="1" style="border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 60%; min-width: 40ch;">
# <strong class="font-bold ">Code output test:</strong>  <div style="padding: 0; margin-top: 10px;">
#     <div style="margin-bottom: 5px;">
# <button onclick="selectPickOption('d50eaa68-5d39-44ce-b338-a83b8c89e880', 0, 'Short')" data-orig-text="1. Short" type="button" class="uk-btn uk-btn-default" style="width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: normal; opacity: 1;">1. Short</button>    </div>
#     <div style="margin-bottom: 5px;">
# ...

# %%
# Test in prompt message (the hard case)
test_msgid = "_final_prompt_test"
test_pickid = str(uuid.uuid4())
test_options = [
    'best of times', 
    'worst of times', 
    'age of wisdom', 
    'age of foolishness with some longer text to test wrapping behavior'
]
test_prompt = 'Final test - It was the'

widget = _pick_one_ft(test_msgid, test_pickid, test_options, test_prompt, selected=3, active=True)
msg_id = add_msg(content='Final prompt test', msg_type='prompt', output=to_xml(widget))
print(f"Created prompt message: {msg_id}")
# Out:
# Created prompt message: _d5f12904

# %% [markdown]
# Final prompt test
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# <div data-pick-container data-msgid="_final_prompt_test" data-pickid="ccff9ae1-dd16-46e2-a25d-c3b2e092264e" data-selected="3" style="border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 60%; min-width: 40ch;">
# <strong class="font-bold ">Final test - It was the</strong>  <div style="padding: 0; margin-top: 10px;">
#     <div style="margin-bottom: 5px;">
# <button onclick="selectPickOption('ccff9ae1-dd16-46e2-a25d-c3b2e092264e', 0, 'best of times')" data-orig-text="1. best of times" type="button" class="uk-btn uk-btn-default" style="width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: normal; opacity: 1;">1. best of times</button>    </div>
#     <div style="margin-bottom: 5px;">
# <button onclick="selectPickOption('ccff9ae1-dd16-46e2-a25d-c3b2e092264e', 1, 'worst of times')" data-orig-text="2. worst of times" type="button" class="uk-btn uk-btn-default" style="width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: normal; opacity: 1;">2. worst of times</button>    </div>
#     <div style="margin-bottom: 5px;">
# <button onclick="selectPickOption('ccff9ae1-dd16-46e2-a25d-c3b2e092264e', 2, 'age of wisdom')" data-orig-text="3. age of wisdom" type="button" class="uk-btn uk-btn-default" style="width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: normal; opacity: 1;">3. age of wisdom</button>    </div>
#     <div style="margin-bottom: 5px;">
# <button onclick="selectPickOption('ccff9ae1-dd16-46e2-a25d-c3b2e092264e', 3, 'age of foolishness with some longer text to test wrapping behavior')" data-orig-text="4. age of foolishness with some longer text to test wrapping behavior" type="button" class="uk-btn uk-btn-primary" style="width: 100%; display: flex; flex-wrap: wrap; justify-content: flex-start; white-space: normal; word-wrap: break-word; text-align: left; height: auto; min-height: fit-content; font-weight: bold; opacity: 1;">✓ 4. age of foolishness with some longer text to test wrapping behavior (selected)</button>    </div>
#   </div>
# </div>

# %% [markdown]
# Awesome! Problem solved. You rule.
#
# But let's add some polish, ok?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Excellent! Glad we got it working! 🎉
#
# Yes, let's add some polish! What improvements would you like to make? Here are some ideas:
#
# **Visual polish:**
# - Better spacing/padding
# - Hover effects on buttons
# - Smooth transitions when selecting
# - Better color contrast or theming
# - Icons or visual indicators
#
# **Functional polish:**
# - Keyboard navigation (arrow keys to move between options, Enter to select)
# - Better disabled state styling
# - Animation when switching selection
# - Accessibility improvements (ARIA labels, focus management)
#
# **Code polish:**
# - Cleaner function signature
# - Better documentation
# - Error handling
# - Configuration options (colors, sizes, etc.)
#
# What aspects would you like to focus on? Or do you have specific polish ideas in mind?

# %% [markdown]
# Horizontal sizing: adapt to text with max-height 60%.
#
# Give me only the changes, no need to re-genrate all code.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Here are the changes:
#
# **In `_pick_one_ft` function:**
#
# Change this line:
# ```python
# stl = "border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 400px;"
# ```
#
# To:
# ```python
# stl = "border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 60%; width: fit-content;"
# ```
#
# This will:
# - Make the container adapt to content width (via `width: fit-content`)
# - Cap it at 60% of parent width (via `max-width: 60%`)

# %% [markdown]
# Ummm, now the div container changes noticiably size depending of what option is selected.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Ah, right! The container is resizing because `width: fit-content` adapts to the content, and the selected button has extra text ("✓" and "(selected)").
#
# **Fix: Set a minimum width to prevent shrinking**
#
# Change:
# ```python
# stl = "border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 60%; width: fit-content;"
# ```
#
# To:
# ```python
# stl = "border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 60%; min-width: min-content;"
# ```
#
# Or better yet, calculate width based on the longest option to keep it stable:
#
# ```python
# # At the start of _pick_one_ft, before creating btns:
# # Calculate a stable width - find longest option text
# max_opt_len = max(len(f"{i+1}. {opt} (selected)") for i, opt in enumerate(options))
# # Use ch units (character width) for more predictable sizing
# min_width = min(max_opt_len * 0.6, 40)  # Cap at reasonable size
#
# stl = f"border: 1px solid var(--bs-border-color, #ccc); padding: 10px; margin: 10px 0; border-radius: 5px; max-width: 60%; min-width: {min_width}ch;"
# ```
#
# Which approach do you prefer?

# %% [markdown]
# Both works equally well, but I was going to propone some heuristic to calculate width, so second one.
#
# Now, te height also changes depending of the height of the selected button. But I think we can live with that.
#
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Good call on the width calculation! And yes, the height variation is probably acceptable since it's just accommodating wrapped text.
#
# What would you like to work on next with the widget?
#
# Some ideas if you're looking for inspiration:
# - Hover effects or transitions
# - Keyboard navigation
# - Different visual themes/styles
# - Accessibility improvements
# - Any other polish or features you have in mind
#
# Or are we done with the widget and ready to move on to something else?

# %% [markdown]
# # Exploring

# %% [markdown]
# Now, that we got a working solution I want to explore other ways. You know tha basis of the problem and for what it will be used. You know also we're in SolveIt and got tools, have FastHTML and MonsterUI at our disposa, and in fact, anything we'd need.
#
# What other solutions or approaches would improve the code, make it more robust, more flexible? Think out of the box.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Great question! Let me think about this from different angles:
#
# **Current approach limitations:**
# - Heavy inline styles (verbose, hard to maintain)
# - Separate JS handler from widget
# - Fighting against SolveIt's post-processing
# - Tightly coupled to UIKit/MonsterUI class names
#
# **Alternative approaches to explore:**
#
# 1. **Scoped CSS with `<style>` injection**
#    - Include a `<style>` tag inside the widget with a unique selector prefix
#    - No inline styles, cleaner HTML, immune to post-processing
#
# 2. **Shadow DOM / Web Components**
#    - Encapsulate the widget completely - external styles can't penetrate
#    - True isolation from SolveIt's transforms
#    - Would require defining a custom element
#
# 3. **HTMX for interactivity (instead of JS)**
#    - Use `hx-post`/`hx-get` to handle selection server-side
#    - Widget re-renders on selection
#    - Better state management, works without JS enabled
#    - Fits the FastHTML philosophy better
#
# 4. **Data attributes + CSS selectors**
#    - Use `data-selected` attributes and CSS `[data-selected="true"]` selectors
#    - Separate concerns: structure (HTML) vs presentation (CSS) vs state (data attrs)
#
# 5. **Injecting CSS via `add_html` with `hx-swap-oob`**
#    - Dynamically inject styles into the page head
#    - Widget HTML stays clean
#
# Which approach(es) interest you most? I'd suggest **#1 (Scoped CSS)** or **#3 (HTMX)** as the most promising. Want to prototype one?

# %% [markdown]
# 1. Promising (and we got some helper preinstaled in the browser)
# 2. Don't like, at least for now
# 3. and 5. We should instantiate a server with JupyUvi or our own. No for this kind of widgets
# 4. Promising
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Excellent! Let's explore **#1 (Scoped CSS)** and **#4 (Data attributes + CSS)** - they work well together actually.
#
# **The approach:**
# - Use data attributes for state (`data-selected`, `data-option-index`)
# - Include a scoped `<style>` block with unique selector (using `pickid`)
# - Minimal inline styles, just structural stuff
# - CSS handles all the visual styling
# - Immune to SolveIt's class additions
#
# **Benefits:**
# - Clean, readable HTML
# - Easy to maintain/theme
# - CSS cascade works naturally
# - Post-processing can't break our styling (specificity wins)
#
# Let me prototype this:
#
# ```python
# def _pick_one_ft_v2(msgid, pickid, options, prompt_text, selected, active) -> FT:
#     """Generate a styled button list widget using scoped CSS
#
#     Args:
#         msgid: Message ID for tracking
#         pickid: Unique picker ID for scoping CSS and JavaScript
#         options: List of option strings to display
#         prompt_text: Header text for the widget
#         selected: Index of selected option (or None)
#         active: If True, buttons are interactive; if False, disabled
#
#     Returns:
#         FT object (FastHTML component tree)
#     """
#
#     # Calculate width
#     max_opt_len = max(len(f"{i+1}. {opt} (selected)") for i, opt in enumerate(options))
#     min_width = min(max_opt_len * 0.6, 40)
#
#     # Scoped CSS - uses pickid as unique selector
#     scoped_css = Style(f"""
#         [data-pickid="{pickid}"] {{
#             border: 1px solid var(--bs-border-color, #ccc);
#             padding: 10px;
#             margin: 10px 0;
#             border-radius: 5px;
#             max-width: 60%;
#             min-width: {min_width}ch;
#         }}
#
#         [data-pickid="{pickid}"] .pick-options {{
#             padding: 0;
#             margin-top: 10px;
#         }}
#
#         [data-pickid="{pickid}"] .pick-option {{
#             margin-bottom: 5px;
#         }}
#
#         [data-pickid="{pickid}"] .pick-btn {{
#             width: 100%;
#             display: flex;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             white-space: normal;
#             word-wrap: break-word;
#             text-align: left;
#             height: auto;
#             min-height: fit-content;
#         }}
#
#         [data-pickid="{pickid}"] .pick-btn[data-selected="true"] {{
#             font-weight: bold;
#         }}
#
#         [data-pickid="{pickid}"] .pick-btn[data-selected="false"]:not(:disabled) {{
#             font-weight: normal;
#         }}
#
#         [data-pickid="{pickid}"] .pick-btn:disabled {{
#             opacity: 0.5;
#         }}
#     """)
#
#     # Build buttons with data attributes
#     btns = [
#         Div(
#             Button(
#                 f"{'✓ ' if selected==i else ''}{i+1}. {opt}{' (selected)' if selected==i else ''}",
#                 onclick=f"selectPickOption('{pickid}', {i}, '{opt}')" if active else None,
#                 disabled=not active and selected != i,
#                 cls=f"pick-btn uk-btn {'uk-btn-primary' if selected==i else 'uk-btn-default'}",
#                 submit=False,
#                 data_orig_text=f"{i+1}. {opt}",
#                 data_selected="true" if selected==i else "false",
#                 data_option_index=i
#             ),
#             cls="pick-option"
#         ) for i, opt in enumerate(options)
#     ]
#
#     attrs = {
#         'data-pick-container': True,
#         'data-msgid': msgid,
#         'data-pickid': pickid,
#         'data-selected': selected if selected is not None else ''
#     } if active else {}
#
#     return Div(
#         scoped_css,
#         Strong(prompt_text),
#         Div(*btns, cls="pick-options"),
#         **attrs
#     )
# ```
#
# **Key changes:**
# 1. All styling in `<style>` block scoped by `[data-pickid="{pickid}"]`
# 2. Semantic class names: `pick-btn`, `pick-options`, `pick-option`
# 3. State via data attributes: `data-selected`, `data-option-index`
# 4. No inline styles except in CSS
# 5. CSS specificity beats any added classes
#
# Want to test this? We might need to update the JS handler to also set `data-selected` attributes.

# %% [markdown]
# FastHTML preinstall awesome gnat's css-scope-inline, which is just this:
#
# ```javascript
# // 🌘 CSS Scope Inline (https://github.com/gnat/css-scope-inline)
# window.cssScopeCount ??= 1
# // Let extra copies share the scope count.
# window.cssScope ??= new MutationObserver(mutations => {
#     // Allow 1 observer.
#     document?.body?.querySelectorAll('style:not([ready])').forEach(node => {
#         // Faster than walking MutationObserver results when recieving subtree (DOM swap, htmx, ajax, jquery).
#         var scope = 'me__' + (window.cssScopeCount++)
#         // Ready. Make unique scope, example: .me__1234
#         node.parentNode.classList.add(scope)
#         node.textContent = node.textContent.replace(/(?:^|\.|(\s|[^a-zA-Z0-9\-\_]))(me|this|self)(?![a-zA-Z])/g, '$1.' + scope)// Can use: me this self
#         .replace(/((@keyframes|animation:|animation-name:)[^{};]*)\.me__/g, '$1me__')// Optional. Removes need to escape names, ex: "\.me"
#         .replace(/(?:@media)\s(xs-|sm-|md-|lg-|xl-|sm|md|lg|xl|xx)/g, // Optional. Responsive design. Mobile First (above breakpoint): 🟢 None sm md lg xl xx 🏁  Desktop First (below breakpoint): 🏁 xs- sm- md- lg- xl- None 🟢 *- matches must be first!
#         (match, part1) => {
#             return '@media ' + ({
#                 'sm': '(min-width: 640px)',
#                 'md': '(min-width: 768px)',
#                 'lg': '(min-width: 1024px)',
#                 'xl': '(min-width: 1280px)',
#                 'xx': '(min-width: 1536px)',
#                 'xs-': '(max-width: 639px)',
#                 'sm-': '(max-width: 767px)',
#                 'md-': '(max-width: 1023px)',
#                 'lg-': '(max-width: 1279px)',
#                 'xl-': '(max-width: 1535px)'
#             }[part1])
#         }
#         )
#         node.setAttribute('ready', '')
#     }
#     )
# }
# ).observe(document.documentElement, {
#     childList: true,
#     subtree: true
# })
# ```
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Oh wow! That's **perfect**! `css-scope-inline` automatically scopes `<style>` tags using `me`, `this`, or `self` as a placeholder!
#
# This makes it even cleaner - we don't need to manually inject the `pickid` everywhere. Let me revise:
#
# ```python
# def _pick_one_ft_v2(msgid, pickid, options, prompt_text, selected, active) -> FT:
#     """Generate a styled button list widget using css-scope-inline
#
#     Uses 'me' keyword which gets auto-scoped by css-scope-inline to parent element.
#     """
#
#     # Calculate width
#     max_opt_len = max(len(f"{i+1}. {opt} (selected)") for i, opt in enumerate(options))
#     min_width = min(max_opt_len * 0.6, 40)
#
#     # Scoped CSS - 'me' gets replaced with unique class by css-scope-inline
#     scoped_css = Style(f"""
#         me {{
#             border: 1px solid var(--bs-border-color, #ccc);
#             padding: 10px;
#             margin: 10px 0;
#             border-radius: 5px;
#             max-width: 60%;
#             min-width: {min_width}ch;
#         }}
#
#         me .pick-options {{
#             padding: 0;
#             margin-top: 10px;
#         }}
#
#         me .pick-option {{
#             margin-bottom: 5px;
#         }}
#
#         me .pick-btn {{
#             width: 100%;
#             display: flex;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             white-space: normal;
#             word-wrap: break-word;
#             text-align: left;
#             height: auto;
#             min-height: fit-content;
#         }}
#
#         me .pick-btn[data-selected="true"] {{
#             font-weight: bold;
#         }}
#
#         me .pick-btn[data-selected="false"] {{
#             font-weight: normal;
#         }}
#
#         me .pick-btn:disabled {{
#             opacity: 0.5;
#         }}
#     """)
#
#     # Build buttons with data attributes
#     btns = [
#         Div(
#             Button(
#                 f"{'✓ ' if selected==i else ''}{i+1}. {opt}{' (selected)' if selected==i else ''}",
#                 onclick=f"selectPickOption('{pickid}', {i}, '{opt}')" if active else None,
#                 disabled=not active and selected != i,
#                 cls=f"pick-btn uk-btn {'uk-btn-primary' if selected==i else 'uk-btn-default'}",
#                 submit=False,
#                 data_orig_text=f"{i+1}. {opt}",
#                 data_selected="true" if selected==i else "false",
#                 data_option_index=i
#             ),
#             cls="pick-option"
#         ) for i, opt in enumerate(options)
#     ]
#
#     attrs = {
#         'data-pick-container': True,
#         'data-msgid': msgid,
#         'data-pickid': pickid,
#         'data-selected': selected if selected is not None else ''
#     } if active else {}
#
#     return Div(
#         scoped_css,
#         Strong(prompt_text),
#         Div(*btns, cls="pick-options"),
#         **attrs
#     )
# ```
#
# **Also need to update JS handler to set `data-selected` attributes:**
#
# ```python
# hdlr_v2 = Script("""
# window.selectPickOption = function(pickid, optionIdx, optionText) {
#     const container = document.querySelector(`[data-pickid="${pickid}"]`);
#     if (!container) { console.error('Container not found for pickid:', pickid); return; }
#     container.dataset.selected = optionIdx;
#
#     container.querySelectorAll('.pick-btn').forEach((btn, idx) => {
#         btn.disabled = false;
#
#         if (idx === optionIdx) {
#             // Selected
#             btn.classList.remove('uk-btn-default');
#             btn.classList.add('uk-btn-primary');
#             btn.dataset.selected = 'true';
#             const origText = btn.dataset.origText;
#             btn.textContent = `✓ ${origText} (selected)`;
#         } else {
#             // Unselected
#             btn.classList.remove('uk-btn-primary');
#             btn.classList.add('uk-btn-default');
#             btn.dataset.selected = 'false';
#             btn.textContent = btn.dataset.origText;
#         }
#     });
# };
# """)
# ```
#
# Want to test this cleaner version?

# %% [markdown]
# # v2

# %%
def _pick_one_ft_v2(msgid, pickid, options, prompt_text, selected, active):
    max_opt_len = max(len(f"{i+1}. {opt} (selected)") for i, opt in enumerate(options))
    min_width = min(max_opt_len * 0.6, 40)
    
    scoped_css = Style(f"""
        me {{
            border: 1px solid var(--bs-border-color, #ccc);
            padding: 10px;
            margin: 10px 0;
            border-radius: 5px;
            max-width: 60%;
            min-width: {min_width}ch;
        }}
        me .pick-options {{ padding: 0; margin-top: 10px; }}
        me .pick-option {{ margin-bottom: 5px; }}
        me .pick-btn {{
            width: 100%;
            display: flex;
            flex-wrap: wrap;
            justify-content: flex-start;
            white-space: normal;
            word-wrap: break-word;
            text-align: left;
            height: auto;
            min-height: fit-content;
        }}
        me .pick-btn[data-selected="true"] {{ font-weight: bold; }}
        me .pick-btn[data-selected="false"] {{ font-weight: normal; }}
        me .pick-btn:disabled {{ opacity: 0.5; }}
    """)
    
    btns = [Div(Button(f"{'✓ ' if selected==i else ''}{i+1}. {opt}{' (selected)' if selected==i else ''}", 
                       onclick=f"selectPickOption('{pickid}', {i}, '{opt}')" if active else None, disabled=not active and selected != i,
                       cls=f"pick-btn uk-btn {'uk-btn-primary' if selected==i else 'uk-btn-default'}", submit=False,
                       data_orig_text=f"{i+1}. {opt}", data_selected="true" if selected==i else "false", data_option_index=i), 
                cls="pick-option") for i, opt in enumerate(options)]
    
    attrs = {'data-pick-container': True, 'data-msgid': msgid, 'data-pickid': pickid, 
             'data-selected': selected if selected is not None else ''} if active else {}
    
    return Div(scoped_css, Strong(prompt_text), Div(*btns, cls="pick-options"), **attrs)

# %%
hdlr_v2 = Script("""
window.selectPickOption = function(pickid, optionIdx, optionText) {
    const container = document.querySelector(`[data-pickid="${pickid}"]`);
    if (!container) { console.error('Container not found for pickid:', pickid); return; }
    container.dataset.selected = optionIdx;
    
    container.querySelectorAll('.pick-btn').forEach((btn, idx) => {
        btn.disabled = false;
        
        if (idx === optionIdx) {
            btn.classList.remove('uk-btn-default');
            btn.classList.add('uk-btn-primary');
            btn.dataset.selected = 'true';
            const origText = btn.dataset.origText;
            btn.textContent = `✓ ${origText} (selected)`;
        } else {
            btn.classList.remove('uk-btn-primary');
            btn.classList.add('uk-btn-default');
            btn.dataset.selected = 'false';
            btn.textContent = btn.dataset.origText;
        }
    });
};
""")

show(hdlr_v2)
# Out:
# <script>
# window.selectPickOption = function(pickid, optionIdx, optionText) {
#     const container = document.querySelector(`[data-pickid="${pickid}"]`);
#     if (!container) { console.error('Container not found for pickid:', pickid); return; }
#     container.dataset.selected = optionIdx;
#
#     container.querySelectorAll('.pick-btn').forEach((btn, idx) => {
#         btn.disabled = false;
#
#         if (idx === optionIdx) {
#             btn.classList.remove('uk-btn-default');
#             btn.classList.add('uk-btn-primary');
#             btn.dataset.selected = 'true';
#             const origText = btn.dataset.origText;
#             btn.textContent = `✓ ${origText} (selected)`;
#         } else {
#             btn.classList.remove('uk-btn-primary');
#             btn.classList.add('uk-btn-default');
#             btn.dataset.selected = 'false';
#             btn.textContent = btn.dataset.origText;
#         }
#     });
# };
# </script>

# %%
test_msgid = "test_v2_code"
test_pickid = str(uuid.uuid4())
test_options = ["Short", "Second option with much longer text contents Lorem ipsum dolor sit amet, consectetur adipiscing elit.", "Third"]
test_prompt = "V2 Code output test:"

widget = _pick_one_ft_v2(test_msgid, test_pickid, test_options, test_prompt, selected=1, active=True)
show(widget)
# Out:
# <div data-pick-container data-msgid="test_v2_code" data-pickid="55627073-f040-461a-b10d-aaf30df9e7f6" data-selected="1">
#   <style>
#         me {
#             border: 1px solid var(--bs-border-color, #ccc);
#             padding: 10px;
#             margin: 10px 0;
#             border-radius: 5px;
#             max-width: 60%;
#             min-width: 40ch;
#         }
#         me .pick-options { padding: 0; margin-top: 10px; }
#         me .pick-option { margin-bottom: 5px; }
#         me .pick-btn {
#             width: 100%;
#             display: flex;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             white-space: normal;
#             word-wrap: break-word;
#             text-align: left;
#             height: auto;
#             min-height: fit-content;
#         }
#         me .pick-btn[data-selected="true"] { font-weight: bold; }
#         me .pick-btn[data-selected="false"] { font-weight: normal; }
# ...

# %%
test_msgid = "_v2_prompt_test"
test_pickid = str(uuid.uuid4())
test_options = ['best of times', 'worst of times', 'age of wisdom', 'age of foolishness with some longer text to test wrapping behavior']
test_prompt = 'V2 Prompt test - It was the'

widget = _pick_one_ft_v2(test_msgid, test_pickid, test_options, test_prompt, selected=3, active=True)
msg_id = add_msg(content='V2 prompt test', msg_type='prompt', output=to_xml(widget))
print(f"Created prompt message: {msg_id}")
# Out:
# Created prompt message: _14248b82

# %% [markdown]
# V2 prompt test
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# <div data-pick-container data-msgid="_v2_prompt_test" data-pickid="a5f44e50-c70e-4498-aefa-8c1d72cb14b9" data-selected="3">
#   <style>
#         me {
#             border: 1px solid var(--bs-border-color, #ccc);
#             padding: 10px;
#             margin: 10px 0;
#             border-radius: 5px;
#             max-width: 60%;
#             min-width: 40ch;
#         }
#         me .pick-options { padding: 0; margin-top: 10px; }
#         me .pick-option { margin-bottom: 5px; }
#         me .pick-btn {
#             width: 100%;
#             display: flex;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             white-space: normal;
#             word-wrap: break-word;
#             text-align: left;
#             height: auto;
#             min-height: fit-content;
#         }
#         me .pick-btn[data-selected="true"] { font-weight: bold; }
#         me .pick-btn[data-selected="false"] { font-weight: normal; }
#         me .pick-btn:disabled { opacity: 0.5; }
#     </style>
# <strong class="font-bold ">V2 Prompt test - It was the</strong>  <div class="pick-options">
#     <div class="pick-option">
# <button onclick="selectPickOption('a5f44e50-c70e-4498-aefa-8c1d72cb14b9', 0, 'best of times')" data-orig-text="1. best of times" data-selected="false" data-option-index="0" type="button" class="uk-btn pick-btn uk-btn uk-btn-default">1. best of times</button>    </div>
#     <div class="pick-option">
# <button onclick="selectPickOption('a5f44e50-c70e-4498-aefa-8c1d72cb14b9', 1, 'worst of times')" data-orig-text="2. worst of times" data-selected="false" data-option-index="1" type="button" class="uk-btn pick-btn uk-btn uk-btn-default">2. worst of times</button>    </div>
#     <div class="pick-option">
# <button onclick="selectPickOption('a5f44e50-c70e-4498-aefa-8c1d72cb14b9', 2, 'age of wisdom')" data-orig-text="3. age of wisdom" data-selected="false" data-option-index="2" type="button" class="uk-btn pick-btn uk-btn uk-btn-default">3. age of wisdom</button>    </div>
#     <div class="pick-option">
# <button onclick="selectPickOption('a5f44e50-c70e-4498-aefa-8c1d72cb14b9', 3, 'age of foolishness with some longer text to test wrapping behavior')" data-orig-text="4. age of foolishness with some longer text to test wrapping behavior" data-selected="true" data-option-index="3" type="button" class="uk-btn pick-btn uk-btn uk-btn-primary">✓ 4. age of foolishness with some longer text to test wrapping behavior (selected)</button>    </div>
#   </div>
# </div>

# %% [markdown]
# Good. It works fine.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Excellent! So we now have two working versions:
#
# **V1 (original):** Inline styles everywhere
# **V2 (scoped CSS):** Clean HTML, styles in `<style>` block with `me` keyword
#
# **V2 advantages:**
# - Much cleaner HTML
# - Easier to maintain/modify styles
# - Better separation of concerns
# - Immune to post-processing class additions
# - Smaller HTML output (styles defined once, not repeated per button)
#
# Want to make V2 the official version and replace the original `_pick_one_ft`? Or would you like to explore any other improvements first?

# %% [markdown]
# It's Ok for today. Great session!
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Thank you! This was a fantastic deep dive! 🎉
#
# We went from fighting bullets and text alignment issues to a clean, robust solution using scoped CSS. Great problem-solving journey!
#
# **What we accomplished:**
# - ✅ Fixed bullet points (switched from `Ul/Li` to `Div`)
# - ✅ Fixed text alignment (flex + justify-content)
# - ✅ Fixed text wrapping/clipping (flex-wrap + height: auto)
# - ✅ Made it work in both code and prompt message outputs
# - ✅ Refactored to clean scoped CSS approach with `css-scope-inline`
# - ✅ Adaptive width sizing with character units
#
# The V2 version is production-ready whenever you need it. Feel free to come back if you want to add more polish or explore other features!
#
# Happy coding! 🚀

# %% [markdown]
# # v3

# %% [markdown]
# Hey again. I want to explore one more option for CSS handling. I like css-scope-inline solution, but I don't know if is the appropiate one for widgets that will be instantiated potentially many times. I've used @scope rules frecuently in other projects and it works pretty well. It would allow our widget to reuse CSS and at the same time avoid post-processing collisions. If we can make it work, we could further reduce the component.
#
# Worth exploring?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Absolutely worth exploring! `@scope` is a modern CSS feature that's perfect for this use case.
#
# **Benefits of `@scope` over `css-scope-inline`:**
# - Native CSS feature (no JS processing needed)
# - Styles can be shared across multiple instances (define once, use many times)
# - Better performance (browser-native scoping)
# - Cleaner separation: one `<style>` block in document head, not per widget
#
# **The approach:**
# ```css
# @scope ([data-pickid="xyz"]) {
#   .pick-btn { /* styles */ }
# }
# ```
#
# Or even better, use a scoping root that works for all instances:
# ```css
# @scope ([data-pick-container]) {
#   .pick-btn { /* styles */ }
#   .pick-options { /* styles */ }
# }
# ```
#
# **Implementation strategy:**
# 1. Single `<style>` block injected once (maybe via `add_html` with `hx-swap-oob` to head)
# 2. Widget HTML becomes super minimal - just structure + classes
# 3. All instances share the same CSS rules
#
# **Potential issue to test:**
# - Browser support (Safari added it recently, check if SolveIt's browser supports it)
# - Does SolveIt's post-processing interfere with `@scope` blocks?
#
# Want me to prototype a V3 using `@scope`?

# %% [markdown]
# - Browser support: `css.at-rules.scope` broadly supported according to MDN; `css.selectors.nesting.at-scope` WIP in Safari, not upoorted in Opera. Safari is the new IW, not releavan for our purposes. Opera who?
# - Does SolveIt's post-processing interfere with @scope blocks? Probably not, but it's best to check.
#
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Perfect! Let's prototype V3 with `@scope`:

# %%
# V3: Using @scope for reusable, scoped styles

# Global styles (inject once, ideally in head or at start)
pick_widget_styles = Style("""
@scope ([data-pick-container]) {
    :scope {
        border: 1px solid var(--bs-border-color, #ccc);
        padding: 10px;
        margin: 10px 0;
        border-radius: 5px;
    }
    
    .pick-options {
        padding: 0;
        margin-top: 10px;
    }
    
    .pick-option {
        margin-bottom: 5px;
    }
    
    .pick-btn {
        width: 100%;
        display: flex;
        flex-wrap: wrap;
        justify-content: flex-start;
        white-space: normal;
        word-wrap: break-word;
        text-align: left;
        height: auto;
        min-height: fit-content;
    }
    
    .pick-btn[data-selected="true"] {
        font-weight: bold;
    }
    
    .pick-btn[data-selected="false"] {
        font-weight: normal;
    }
    
    .pick-btn:disabled {
        opacity: 0.5;
    }
}
""")

def _pick_one_ft_v3(msgid, pickid, options, prompt_text, selected, active):
    """Generate widget using @scope - minimal HTML, shared CSS"""
    
    # Calculate width - now needs inline style since it's dynamic per instance
    max_opt_len = max(len(f"{i+1}. {opt} (selected)") for i, opt in enumerate(options))
    min_width = min(max_opt_len * 0.6, 40)
    
    btns = [
        Div(
            Button(
                f"{'✓ ' if selected==i else ''}{i+1}. {opt}{' (selected)' if selected==i else ''}",
                onclick=f"selectPickOption('{pickid}', {i}, '{opt}')" if active else None,
                disabled=not active and selected != i,
                cls=f"pick-btn uk-btn {'uk-btn-primary' if selected==i else 'uk-btn-default'}",
                submit=False,
                data_orig_text=f"{i+1}. {opt}",
                data_selected="true" if selected==i else "false",
                data_option_index=i
            ),
            cls="pick-option"
        ) for i, opt in enumerate(options)
    ]
    
    attrs = {
        'data-pick-container': True,
        'data-msgid': msgid,
        'data-pickid': pickid,
        'data-selected': selected if selected is not None else ''
    } if active else {}
    
    # Only dynamic styles inline
    return Div(
        Strong(prompt_text),
        Div(*btns, cls="pick-options"),
        style=f"max-width: 60%; min-width: {min_width}ch;",
        **attrs
    )

# %%
# First, inject the global styles once
show(pick_widget_styles)
# Out:
# <style>
# @scope ([data-pick-container]) {
#     :scope {
#         border: 1px solid var(--bs-border-color, #ccc);
#         padding: 10px;
#         margin: 10px 0;
#         border-radius: 5px;
#     }
#
#     .pick-options {
#         padding: 0;
#         margin-top: 10px;
#     }
#
#     .pick-option {
#         margin-bottom: 5px;
#     }
#
#     .pick-btn {
#         width: 100%;
#         display: flex;
#         flex-wrap: wrap;
#         justify-content: flex-start;
#         white-space: normal;
#         word-wrap: break-word;
#         text-align: left;
#         height: auto;
#         min-height: fit-content;
#     }
#
#     .pick-btn[data-selected="true"] {
#         font-weight: bold;
#     }
#
#     .pick-btn[data-selected="false"] {
#         font-weight: normal;
#     }
#
#     .pick-btn:disabled {
#         opacity: 0.5;
#     }
# }
# </style>

# %%
# Test in code output
test_msgid = "test_v3_code"
test_pickid = str(uuid.uuid4())
test_options = ["Short", "Second option with much longer text contents Lorem ipsum dolor sit amet, consectetur adipiscing elit.", "Third"]
test_prompt = "V3 Code (@scope):"

widget = _pick_one_ft_v3(test_msgid, test_pickid, test_options, test_prompt, selected=1, active=True)
show(widget)
# Out:
# <div data-pick-container data-msgid="test_v3_code" data-pickid="e2f48923-aedf-404b-ab14-60e867113648" data-selected="1" style="max-width: 60%; min-width: 40ch;">
# <strong class="font-bold ">V3 Code (@scope):</strong>  <div class="pick-options">
#     <div class="pick-option">
# <button onclick="selectPickOption('e2f48923-aedf-404b-ab14-60e867113648', 0, 'Short')" data-orig-text="1. Short" data-selected="false" data-option-index="0" type="button" class="uk-btn pick-btn uk-btn uk-btn-default">1. Short</button>    </div>
#     <div class="pick-option">
# ...

# %%
# Test in prompt output
test_msgid = "_v3_prompt_test"
test_pickid = str(uuid.uuid4())
test_options = ['best of times', 'worst of times', 'age of wisdom', 'age of foolishness with longer text']
test_prompt = 'V3 Prompt (@scope) - It was the'

widget = _pick_one_ft_v3(test_msgid, test_pickid, test_options, test_prompt, selected=2, active=True)
msg_id = add_msg(content='V3 prompt test', msg_type='prompt', output=to_xml(widget))
print(f"Created: {msg_id}")
# Out:
# Created: _364dea60

# %% [markdown]
# V3 prompt test
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# <div data-pick-container data-msgid="_v3_prompt_test" data-pickid="e9976e88-e153-465f-86b0-a8276a280f11" data-selected="2" style="max-width: 60%; min-width: 29.4ch;">
# <strong class="font-bold ">V3 Prompt (@scope) - It was the</strong>  <div class="pick-options">
#     <div class="pick-option">
# <button onclick="selectPickOption('e9976e88-e153-465f-86b0-a8276a280f11', 0, 'best of times')" data-orig-text="1. best of times" data-selected="false" data-option-index="0" type="button" class="uk-btn pick-btn uk-btn uk-btn-default">1. best of times</button>    </div>
#     <div class="pick-option">
# <button onclick="selectPickOption('e9976e88-e153-465f-86b0-a8276a280f11', 1, 'worst of times')" data-orig-text="2. worst of times" data-selected="false" data-option-index="1" type="button" class="uk-btn pick-btn uk-btn uk-btn-default">2. worst of times</button>    </div>
#     <div class="pick-option">
# <button onclick="selectPickOption('e9976e88-e153-465f-86b0-a8276a280f11', 2, 'age of wisdom')" data-orig-text="3. age of wisdom" data-selected="true" data-option-index="2" type="button" class="uk-btn pick-btn uk-btn uk-btn-primary">✓ 3. age of wisdom (selected)</button>    </div>
#     <div class="pick-option">
# <button onclick="selectPickOption('e9976e88-e153-465f-86b0-a8276a280f11', 3, 'age of foolishness with longer text')" data-orig-text="4. age of foolishness with longer text" data-selected="false" data-option-index="3" type="button" class="uk-btn pick-btn uk-btn uk-btn-default">4. age of foolishness with longer text</button>    </div>
#   </div>
# </div>

# %% [markdown]
# Works great!
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Excellent! `@scope` works perfectly! 🎉
#
# **V3 wins big:**
# - ✅ Works in both code and prompt outputs
# - ✅ Post-processing doesn't interfere with `@scope`
# - ✅ Styles defined once, shared across all instances
# - ✅ Minimal HTML per widget (just structure + classes)
# - ✅ Only dynamic styles (width) inline
#
# **Comparison:**
#
# | Version | Approach | HTML Size | Maintainability | Performance |
# |---------|----------|-----------|-----------------|-------------|
# | V1 | Inline styles | Large | Hard | OK |
# | V2 | `css-scope-inline` | Medium | Good | Good |
# | V3 | `@scope` | **Smallest** | **Best** | **Best** |

# %%
def _pick_one_ft_v3(msgid, pickid, options, prompt_text, selected, active):
    "Generate widget using @scope - minimal HTML, shared CSS"
    # Calculate width - now needs inline style since it's dynamic per instance
    max_opt_len = max(len(f"{i+1}. {opt} (selected)") for i, opt in enumerate(options))
    min_width = min(max_opt_len * 0.6, 40)
    btns = [Div(cls="pick-option")(Button(
                onclick=f"selectPickOption('{pickid}', {i}, '{opt}')" if active else None,
                disabled=not active and selected != i,
                cls=f"pick-btn uk-btn {'uk-btn-primary' if selected==i else 'uk-btn-default'}",
                submit=False,
                data_orig_text=f"{i+1}. {opt}",
                data_selected="true" if selected==i else "false",
                data_option_index=i
            )(f"{'✓ ' if selected==i else ''}{i+1}. {opt}{' (selected)' if selected==i else ''}")
        ) for i, opt in enumerate(options)]
    attrs = {
        'data-pick-container': True, 'data-msgid': msgid, 'data-pickid': pickid,
        'data-selected': selected if selected is not None else ''
    } if active else {}
    return Div(style=f"max-width: 60%; min-width: {min_width}ch;", **attrs)(
        Strong(prompt_text),
        Div(*btns, cls="pick-options"),
    )
